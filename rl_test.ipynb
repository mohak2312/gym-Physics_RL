# %%
import gym
import gym_Physics_RL
from torch import nn as nn

from rlkit.exploration_strategies.base import PolicyWrappedWithExplorationStrategy
from rlkit.exploration_strategies.epsilon_greedy import EpsilonGreedy
from rlkit.policies.argmax import ArgmaxDiscretePolicy
from rlkit.torch.dqn.double_dqn import DoubleDQNTrainer
from rlkit.torch.networks import Mlp
import rlkit.torch.pytorch_util as ptu
from rlkit.data_management.env_replay_buffer import EnvReplayBuffer
from rlkit.launchers.launcher_util import setup_logger
from rlkit.samplers.data_collector import MdpPathCollector
from rlkit.torch.torch_rl_algorithm import TorchBatchRLAlgorithm


def experiment(variant):
    expl_env = gym.make('Physics_RL-v0')
    eval_env = gym.make('Physics_RL-v0')
    obs_dim = expl_env.observation_space.low.size
    action_dim = eval_env.action_space.n

    qf = Mlp(
        hidden_sizes=[32, 32],
        input_size=obs_dim,
        output_size=action_dim,
    )
    target_qf = Mlp(
        hidden_sizes=[32, 32],
        input_size=obs_dim,
        output_size=action_dim,
    )
    qf_criterion = nn.MSELoss()
    eval_policy = ArgmaxDiscretePolicy(qf)
    expl_policy = PolicyWrappedWithExplorationStrategy(
        EpsilonGreedy(expl_env.action_space),
        eval_policy,
    )
    eval_path_collector = MdpPathCollector(
        eval_env,
        eval_policy,
    )
    expl_path_collector = MdpPathCollector(
        expl_env,
        expl_policy,
    )
    trainer = DoubleDQNTrainer(
        qf=qf,
        target_qf=target_qf,
        qf_criterion=qf_criterion,
        **variant['trainer_kwargs']
    )
    replay_buffer = EnvReplayBuffer(
        variant['replay_buffer_size'],
        expl_env,
    )
    algorithm = TorchBatchRLAlgorithm(
        trainer=trainer,
        exploration_env=expl_env,
        evaluation_env=eval_env,
        exploration_data_collector=expl_path_collector,
        evaluation_data_collector=eval_path_collector,
        replay_buffer=replay_buffer,
        **variant['algorithm_kwargs']
    )
    algorithm.to(ptu.device)
    algorithm.train()
# Out:
# doodad not detected

# %%
if __name__ == "__main__":
    # noinspection PyTypeChecker
    variant = dict(
        algorithm="DDQN",
        version="normal",
        layer_size=256,
        replay_buffer_size=int(1E6),
        algorithm_kwargs=dict(
            num_epochs=3000,
            num_eval_steps_per_epoch=5000,
            num_trains_per_train_loop=1000,
            num_expl_steps_per_train_loop=10,
            min_num_steps_before_training=10,
            max_path_length=10,
            batch_size=256,
        ),
        trainer_kwargs=dict(
            discount=0.99,
            learning_rate=3E-4,
        ),
    )
    setup_logger('ddqn-train', variant=variant)
    # ptu.set_gpu_mode(True)  # optionally set the GPU (default=False)
    experiment(variant)
# Out:
# 2019-06-08 21:13:54.963605 Pacific Daylight Time | Variant:
# 2019-06-08 21:13:54.965607 Pacific Daylight Time | {
#   "algorithm": "DDQN",
#   "version": "normal",
#   "layer_size": 256,
#   "replay_buffer_size": 1000000,
#   "algorithm_kwargs": {
#     "num_epochs": 3000,
#     "num_eval_steps_per_epoch": 5000,
#     "num_trains_per_train_loop": 1000,
#     "num_expl_steps_per_train_loop": 10,
#     "min_num_steps_before_training": 10,
#     "max_path_length": 10,
#     "batch_size": 256
#   },
#   "trainer_kwargs": {
#     "discount": 0.99,
#     "learning_rate": 0.0003
#   }
# }
# 2019-06-08 21:14:03.271335 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 0 finished
# ---------------------------------------------  --------------
# replay_buffer/size                               20
# trainer/QF Loss                                   3.4821
# trainer/Y Predictions Mean                        0.23983
# trainer/Y Predictions Std                         0.121231
# trainer/Y Predictions Max                         0.403174
# trainer/Y Predictions Min                        -0.0906651
# exploration/num steps total                      20
# exploration/num paths total                       3
# exploration/path length Mean                     10
# exploration/path length Std                       0
# exploration/path length Max                      10
# exploration/path length Min                      10
# exploration/Rewards Mean                          1
# exploration/Rewards Std                           0
# exploration/Rewards Max                           1
# exploration/Rewards Min                           1
# exploration/Returns Mean                         10
# exploration/Returns Std                           0
# exploration/Returns Max                          10
# exploration/Returns Min                          10
# exploration/Actions Mean                         51.6
# exploration/Actions Std                          26.4431
# exploration/Actions Max                          77
# exploration/Actions Min                          21
# exploration/Num Paths                             1
# exploration/Average Returns                      10
# exploration/env_infos/final/actions Mean          0
# exploration/env_infos/final/actions Std           0
# exploration/env_infos/final/actions Max           0
# exploration/env_infos/final/actions Min           0
# exploration/env_infos/initial/actions Mean        0
# exploration/env_infos/initial/actions Std         0
# exploration/env_infos/initial/actions Max         0
# exploration/env_infos/initial/actions Min         0
# exploration/env_infos/actions Mean                0
# exploration/env_infos/actions Std                 0
# exploration/env_infos/actions Max                 0
# exploration/env_infos/actions Min                 0
# exploration/env_infos/final/Y_Pos_1 Mean        345
# exploration/env_infos/final/Y_Pos_1 Std           0
# exploration/env_infos/final/Y_Pos_1 Max         345
# exploration/env_infos/final/Y_Pos_1 Min         345
# exploration/env_infos/initial/Y_Pos_1 Mean      345
# exploration/env_infos/initial/Y_Pos_1 Std         0
# exploration/env_infos/initial/Y_Pos_1 Max       345
# exploration/env_infos/initial/Y_Pos_1 Min       345
# exploration/env_infos/Y_Pos_1 Mean              345
# exploration/env_infos/Y_Pos_1 Std                 0
# exploration/env_infos/Y_Pos_1 Max               345
# exploration/env_infos/Y_Pos_1 Min               345
# exploration/env_infos/final/Velocity_y Mean      10
# exploration/env_infos/final/Velocity_y Std        0
# exploration/env_infos/final/Velocity_y Max       10
# exploration/env_infos/final/Velocity_y Min       10
# exploration/env_infos/initial/Velocity_y Mean    10
# exploration/env_infos/initial/Velocity_y Std      0
# exploration/env_infos/initial/Velocity_y Max     10
# exploration/env_infos/initial/Velocity_y Min     10
# exploration/env_infos/Velocity_y Mean            10
# exploration/env_infos/Velocity_y Std              0
# exploration/env_infos/Velocity_y Max             10
# exploration/env_infos/Velocity_y Min             10
# exploration/env_infos/final/X_pos_2 Mean        280
# exploration/env_infos/final/X_pos_2 Std           0
# exploration/env_infos/final/X_pos_2 Max         280
# exploration/env_infos/final/X_pos_2 Min         280
# exploration/env_infos/initial/X_pos_2 Mean      280
# exploration/env_infos/initial/X_pos_2 Std         0
# exploration/env_infos/initial/X_pos_2 Max       280
# exploration/env_infos/initial/X_pos_2 Min       280
# exploration/env_infos/X_pos_2 Mean              280
# exploration/env_infos/X_pos_2 Std                 0
# exploration/env_infos/X_pos_2 Max               280
# exploration/env_infos/X_pos_2 Min               280
# evaluation/num steps total                     4996
# evaluation/num paths total                      546
# evaluation/path length Mean                       9.15018
# evaluation/path length Std                        1.02682
# evaluation/path length Max                       10
# evaluation/path length Min                        7
# evaluation/Rewards Mean                           0.246597
# evaluation/Rewards Std                            2.78493
# evaluation/Rewards Max                           10
# evaluation/Rewards Min                          -10
# evaluation/Returns Mean                           2.25641
# evaluation/Returns Std                            6.05562
# evaluation/Returns Max                           19
# evaluation/Returns Min                           -4
# evaluation/Actions Mean                          61.9524
# evaluation/Actions Std                           26.2458
# evaluation/Actions Max                           98
# evaluation/Actions Min                           21
# evaluation/Num Paths                            546
# evaluation/Average Returns                        2.25641
# evaluation/env_infos/final/actions Mean           0
# evaluation/env_infos/final/actions Std            0
# evaluation/env_infos/final/actions Max            0
# evaluation/env_infos/final/actions Min            0
# evaluation/env_infos/initial/actions Mean         0
# evaluation/env_infos/initial/actions Std          0
# evaluation/env_infos/initial/actions Max          0
# evaluation/env_infos/initial/actions Min          0
# evaluation/env_infos/actions Mean                 0
# evaluation/env_infos/actions Std                  0
# evaluation/env_infos/actions Max                  0
# evaluation/env_infos/actions Min                  0
# evaluation/env_infos/final/Y_Pos_1 Mean         297
# evaluation/env_infos/final/Y_Pos_1 Std            0
# evaluation/env_infos/final/Y_Pos_1 Max          297
# evaluation/env_infos/final/Y_Pos_1 Min          297
# evaluation/env_infos/initial/Y_Pos_1 Mean       297
# evaluation/env_infos/initial/Y_Pos_1 Std          0
# evaluation/env_infos/initial/Y_Pos_1 Max        297
# evaluation/env_infos/initial/Y_Pos_1 Min        297
# evaluation/env_infos/Y_Pos_1 Mean               297
# evaluation/env_infos/Y_Pos_1 Std                  0
# evaluation/env_infos/Y_Pos_1 Max                297
# evaluation/env_infos/Y_Pos_1 Min                297
# evaluation/env_infos/final/Velocity_y Mean        5.38645
# evaluation/env_infos/final/Velocity_y Std         2.84633
# evaluation/env_infos/final/Velocity_y Max        10
# evaluation/env_infos/final/Velocity_y Min         1
# evaluation/env_infos/initial/Velocity_y Mean      5.38645
# evaluation/env_infos/initial/Velocity_y Std       2.84633
# evaluation/env_infos/initial/Velocity_y Max      10
# evaluation/env_infos/initial/Velocity_y Min       1
# evaluation/env_infos/Velocity_y Mean              5.35388
# evaluation/env_infos/Velocity_y Std               2.84411
# evaluation/env_infos/Velocity_y Max              10
# evaluation/env_infos/Velocity_y Min               1
# evaluation/env_infos/final/X_pos_2 Mean         346.634
# evaluation/env_infos/final/X_pos_2 Std          132.956
# evaluation/env_infos/final/X_pos_2 Max          579
# evaluation/env_infos/final/X_pos_2 Min          120
# evaluation/env_infos/initial/X_pos_2 Mean       346.634
# evaluation/env_infos/initial/X_pos_2 Std        132.956
# evaluation/env_infos/initial/X_pos_2 Max        579
# evaluation/env_infos/initial/X_pos_2 Min        120
# evaluation/env_infos/X_pos_2 Mean               350.548
# evaluation/env_infos/X_pos_2 Std                131.014
# evaluation/env_infos/X_pos_2 Max                579
# evaluation/env_infos/X_pos_2 Min                120
# time/data storing (s)                             0.000133017
# time/evaluation sampling (s)                      3.95574
# time/exploration sampling (s)                     0.00700434
# time/logging (s)                                  0.0666458
# time/saving (s)                                   0.00952634
# time/training (s)                                 4.09406
# time/epoch (s)                                    8.13311
# time/total (s)                                   10.5608
# Epoch                                             0
# ---------------------------------------------  --------------
# 2019-06-08 21:14:12.746959 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 1 finished
# ---------------------------------------------  --------------
# replay_buffer/size                               30
# trainer/QF Loss                                   7.88793
# trainer/Y Predictions Mean                        2.33443
# trainer/Y Predictions Std                         2.98887
# trainer/Y Predictions Max                         4.35402
# trainer/Y Predictions Min                        -9.96183
# exploration/num steps total                      30
# exploration/num paths total                       4
# exploration/path length Mean                     10
# exploration/path length Std                       0
# exploration/path length Max                      10
# exploration/path length Min                      10
# exploration/Rewards Mean                         -0.1
# exploration/Rewards Std                           3.3
# exploration/Rewards Max                           1
# exploration/Rewards Min                         -10
# exploration/Returns Mean                         -1
# exploration/Returns Std                           0
# exploration/Returns Max                          -1
# exploration/Returns Min                          -1
# exploration/Actions Mean                         65.2
# exploration/Actions Std                          15.5615
# exploration/Actions Max                          80
# exploration/Actions Min                          47
# exploration/Num Paths                             1
# exploration/Average Returns                      -1
# exploration/env_infos/final/actions Mean          0
# exploration/env_infos/final/actions Std           0
# exploration/env_infos/final/actions Max           0
# exploration/env_infos/final/actions Min           0
# exploration/env_infos/initial/actions Mean        0
# exploration/env_infos/initial/actions Std         0
# exploration/env_infos/initial/actions Max         0
# exploration/env_infos/initial/actions Min         0
# exploration/env_infos/actions Mean                0
# exploration/env_infos/actions Std                 0
# exploration/env_infos/actions Max                 0
# exploration/env_infos/actions Min                 0
# exploration/env_infos/final/Y_Pos_1 Mean        345
# exploration/env_infos/final/Y_Pos_1 Std           0
# exploration/env_infos/final/Y_Pos_1 Max         345
# exploration/env_infos/final/Y_Pos_1 Min         345
# exploration/env_infos/initial/Y_Pos_1 Mean      345
# exploration/env_infos/initial/Y_Pos_1 Std         0
# exploration/env_infos/initial/Y_Pos_1 Max       345
# exploration/env_infos/initial/Y_Pos_1 Min       345
# exploration/env_infos/Y_Pos_1 Mean              345
# exploration/env_infos/Y_Pos_1 Std                 0
# exploration/env_infos/Y_Pos_1 Max               345
# exploration/env_infos/Y_Pos_1 Min               345
# exploration/env_infos/final/Velocity_y Mean      10
# exploration/env_infos/final/Velocity_y Std        0
# exploration/env_infos/final/Velocity_y Max       10
# exploration/env_infos/final/Velocity_y Min       10
# exploration/env_infos/initial/Velocity_y Mean    10
# exploration/env_infos/initial/Velocity_y Std      0
# exploration/env_infos/initial/Velocity_y Max     10
# exploration/env_infos/initial/Velocity_y Min     10
# exploration/env_infos/Velocity_y Mean            10
# exploration/env_infos/Velocity_y Std              0
# exploration/env_infos/Velocity_y Max             10
# exploration/env_infos/Velocity_y Min             10
# exploration/env_infos/final/X_pos_2 Mean        237
# exploration/env_infos/final/X_pos_2 Std           0
# exploration/env_infos/final/X_pos_2 Max         237
# exploration/env_infos/final/X_pos_2 Min         237
# exploration/env_infos/initial/X_pos_2 Mean      237
# exploration/env_infos/initial/X_pos_2 Std         0
# exploration/env_infos/initial/X_pos_2 Max       237
# exploration/env_infos/initial/X_pos_2 Min       237
# exploration/env_infos/X_pos_2 Mean              237
# exploration/env_infos/X_pos_2 Std                 0
# exploration/env_infos/X_pos_2 Max               237
# exploration/env_infos/X_pos_2 Min               237
# evaluation/num steps total                     9989
# evaluation/num paths total                     1074
# evaluation/path length Mean                       9.45644
# evaluation/path length Std                        0.858335
# evaluation/path length Max                       10
# evaluation/path length Min                        8
# evaluation/Rewards Mean                           0.627679
# evaluation/Rewards Std                            1.9892
# evaluation/Rewards Max                            1
# evaluation/Rewards Min                          -10
# evaluation/Returns Mean                           5.93561
# evaluation/Returns Std                            5.93299
# evaluation/Returns Max                           10
# evaluation/Returns Min                           -3
# evaluation/Actions Mean                          55.3757
# evaluation/Actions Std                           14.3838
# evaluation/Actions Max                           80
# evaluation/Actions Min                           44
# evaluation/Num Paths                            528
# evaluation/Average Returns                        5.93561
# evaluation/env_infos/final/actions Mean           0
# evaluation/env_infos/final/actions Std            0
# evaluation/env_infos/final/actions Max            0
# evaluation/env_infos/final/actions Min            0
# evaluation/env_infos/initial/actions Mean         0
# evaluation/env_infos/initial/actions Std          0
# evaluation/env_infos/initial/actions Max          0
# evaluation/env_infos/initial/actions Min          0
# evaluation/env_infos/actions Mean                 0
# evaluation/env_infos/actions Std                  0
# evaluation/env_infos/actions Max                  0
# evaluation/env_infos/actions Min                  0
# evaluation/env_infos/final/Y_Pos_1 Mean         297
# evaluation/env_infos/final/Y_Pos_1 Std            0
# evaluation/env_infos/final/Y_Pos_1 Max          297
# evaluation/env_infos/final/Y_Pos_1 Min          297
# evaluation/env_infos/initial/Y_Pos_1 Mean       297
# evaluation/env_infos/initial/Y_Pos_1 Std          0
# evaluation/env_infos/initial/Y_Pos_1 Max        297
# evaluation/env_infos/initial/Y_Pos_1 Min        297
# evaluation/env_infos/Y_Pos_1 Mean               297
# evaluation/env_infos/Y_Pos_1 Std                  0
# evaluation/env_infos/Y_Pos_1 Max                297
# evaluation/env_infos/Y_Pos_1 Min                297
# evaluation/env_infos/final/Velocity_y Mean        5.61174
# evaluation/env_infos/final/Velocity_y Std         2.82689
# evaluation/env_infos/final/Velocity_y Max        10
# evaluation/env_infos/final/Velocity_y Min         1
# evaluation/env_infos/initial/Velocity_y Mean      5.61174
# evaluation/env_infos/initial/Velocity_y Std       2.82689
# evaluation/env_infos/initial/Velocity_y Max      10
# evaluation/env_infos/initial/Velocity_y Min       1
# evaluation/env_infos/Velocity_y Mean              5.62528
# evaluation/env_infos/Velocity_y Std               2.83012
# evaluation/env_infos/Velocity_y Max              10
# evaluation/env_infos/Velocity_y Min               1
# evaluation/env_infos/final/X_pos_2 Mean         351.561
# evaluation/env_infos/final/X_pos_2 Std          133.547
# evaluation/env_infos/final/X_pos_2 Max          580
# evaluation/env_infos/final/X_pos_2 Min          121
# evaluation/env_infos/initial/X_pos_2 Mean       351.561
# evaluation/env_infos/initial/X_pos_2 Std        133.547
# evaluation/env_infos/initial/X_pos_2 Max        580
# evaluation/env_infos/initial/X_pos_2 Min        121
# evaluation/env_infos/X_pos_2 Mean               359.035
# evaluation/env_infos/X_pos_2 Std                132.578
# evaluation/env_infos/X_pos_2 Max                580
# evaluation/env_infos/X_pos_2 Min                121
# time/data storing (s)                             0.000143691
# time/evaluation sampling (s)                      4.7883
# time/exploration sampling (s)                     0.00851269
# time/logging (s)                                  0.0557408
# time/saving (s)                                   0.00679168
# time/training (s)                                 4.43137
# time/epoch (s)                                    9.29086
# time/total (s)                                   20.0185
# Epoch                                             1
# ---------------------------------------------  --------------
# 2019-06-08 21:14:22.679114 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 2 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                                40
# trainer/QF Loss                                    2.32039
# trainer/Y Predictions Mean                         4.18305
# trainer/Y Predictions Std                          3.62381
# trainer/Y Predictions Max                          8.27521
# trainer/Y Predictions Min                        -10.0612
# exploration/num steps total                       40
# exploration/num paths total                        5
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                           1
# exploration/Rewards Std                            0
# exploration/Rewards Max                            1
# exploration/Rewards Min                            1
# exploration/Returns Mean                          10
# exploration/Returns Std                            0
# exploration/Returns Max                           10
# exploration/Returns Min                           10
# exploration/Actions Mean                          25.6
# exploration/Actions Std                           13.8
# exploration/Actions Max                           67
# exploration/Actions Min                           21
# exploration/Num Paths                              1
# exploration/Average Returns                       10
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         345
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          345
# exploration/env_infos/final/Y_Pos_1 Min          345
# exploration/env_infos/initial/Y_Pos_1 Mean       345
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        345
# exploration/env_infos/initial/Y_Pos_1 Min        345
# exploration/env_infos/Y_Pos_1 Mean               345
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                345
# exploration/env_infos/Y_Pos_1 Min                345
# exploration/env_infos/final/Velocity_y Mean        6
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         6
# exploration/env_infos/final/Velocity_y Min         6
# exploration/env_infos/initial/Velocity_y Mean      6
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       6
# exploration/env_infos/initial/Velocity_y Min       6
# exploration/env_infos/Velocity_y Mean              6
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               6
# exploration/env_infos/Velocity_y Min               6
# exploration/env_infos/final/X_pos_2 Mean         426
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          426
# exploration/env_infos/final/X_pos_2 Min          426
# exploration/env_infos/initial/X_pos_2 Mean       426
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        426
# exploration/env_infos/initial/X_pos_2 Min        426
# exploration/env_infos/X_pos_2 Mean               426
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                426
# exploration/env_infos/X_pos_2 Min                426
# evaluation/num steps total                     14986
# evaluation/num paths total                      1595
# evaluation/path length Mean                        9.59117
# evaluation/path length Std                         0.805356
# evaluation/path length Max                        10
# evaluation/path length Min                         8
# evaluation/Rewards Mean                            0.760056
# evaluation/Rewards Std                             1.6068
# evaluation/Rewards Max                             1
# evaluation/Rewards Min                           -10
# evaluation/Returns Mean                            7.28983
# evaluation/Returns Std                             5.27065
# evaluation/Returns Max                            10
# evaluation/Returns Min                            -3
# evaluation/Actions Mean                           31.6346
# evaluation/Actions Std                            22.5636
# evaluation/Actions Max                            80
# evaluation/Actions Min                            21
# evaluation/Num Paths                             521
# evaluation/Average Returns                         7.28983
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          297
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           297
# evaluation/env_infos/final/Y_Pos_1 Min           297
# evaluation/env_infos/initial/Y_Pos_1 Mean        297
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         297
# evaluation/env_infos/initial/Y_Pos_1 Min         297
# evaluation/env_infos/Y_Pos_1 Mean                297
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 297
# evaluation/env_infos/Y_Pos_1 Min                 297
# evaluation/env_infos/final/Velocity_y Mean         5.58733
# evaluation/env_infos/final/Velocity_y Std          2.81423
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.58733
# evaluation/env_infos/initial/Velocity_y Std        2.81423
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.57194
# evaluation/env_infos/Velocity_y Std                2.81422
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          341.488
# evaluation/env_infos/final/X_pos_2 Std           129.747
# evaluation/env_infos/final/X_pos_2 Max           580
# evaluation/env_infos/final/X_pos_2 Min           120
# evaluation/env_infos/initial/X_pos_2 Mean        341.488
# evaluation/env_infos/initial/X_pos_2 Std         129.747
# evaluation/env_infos/initial/X_pos_2 Max         580
# evaluation/env_infos/initial/X_pos_2 Min         120
# evaluation/env_infos/X_pos_2 Mean                347.585
# evaluation/env_infos/X_pos_2 Std                 128.524
# evaluation/env_infos/X_pos_2 Max                 580
# evaluation/env_infos/X_pos_2 Min                 120
# time/data storing (s)                              0.000136712
# time/evaluation sampling (s)                       4.6502
# time/exploration sampling (s)                      0.00766656
# time/logging (s)                                   0.0499353
# time/saving (s)                                    0.00794819
# time/training (s)                                  5.01254
# time/epoch (s)                                     9.72843
# time/total (s)                                    29.9432
# Epoch                                              2
# ---------------------------------------------  ---------------
# 2019-06-08 21:14:32.366878 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 3 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                                50
# trainer/QF Loss                                    4.67279
# trainer/Y Predictions Mean                         3.47495
# trainer/Y Predictions Std                          3.78302
# trainer/Y Predictions Max                          9.46889
# trainer/Y Predictions Min                        -10.0116
# exploration/num steps total                       50
# exploration/num paths total                        6
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                          -0.1
# exploration/Rewards Std                            3.3
# exploration/Rewards Max                            1
# exploration/Rewards Min                          -10
# exploration/Returns Mean                          -1
# exploration/Returns Std                            0
# exploration/Returns Max                           -1
# exploration/Returns Min                           -1
# exploration/Actions Mean                          61.4
# exploration/Actions Std                           18.178
# exploration/Actions Max                           77
# exploration/Actions Min                            9
# exploration/Num Paths                              1
# exploration/Average Returns                       -1
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         345
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          345
# exploration/env_infos/final/Y_Pos_1 Min          345
# exploration/env_infos/initial/Y_Pos_1 Mean       345
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        345
# exploration/env_infos/initial/Y_Pos_1 Min        345
# exploration/env_infos/Y_Pos_1 Mean               345
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                345
# exploration/env_infos/Y_Pos_1 Min                345
# exploration/env_infos/final/Velocity_y Mean        3
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         3
# exploration/env_infos/final/Velocity_y Min         3
# exploration/env_infos/initial/Velocity_y Mean      3
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       3
# exploration/env_infos/initial/Velocity_y Min       3
# exploration/env_infos/Velocity_y Mean              3
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               3
# exploration/env_infos/Velocity_y Min               3
# exploration/env_infos/final/X_pos_2 Mean         137
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          137
# exploration/env_infos/final/X_pos_2 Min          137
# exploration/env_infos/initial/X_pos_2 Mean       137
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        137
# exploration/env_infos/initial/X_pos_2 Min        137
# exploration/env_infos/X_pos_2 Mean               137
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                137
# exploration/env_infos/X_pos_2 Min                137
# evaluation/num steps total                     19979
# evaluation/num paths total                      2174
# evaluation/path length Mean                        8.62349
# evaluation/path length Std                         0.502018
# evaluation/path length Max                        10
# evaluation/path length Min                         8
# evaluation/Rewards Mean                           -0.275586
# evaluation/Rewards Std                             3.52198
# evaluation/Rewards Max                             1
# evaluation/Rewards Min                           -10
# evaluation/Returns Mean                           -2.37651
# evaluation/Returns Std                             0.502018
# evaluation/Returns Max                            -1
# evaluation/Returns Min                            -3
# evaluation/Actions Mean                           69.4773
# evaluation/Actions Std                             7.56201
# evaluation/Actions Max                            80
# evaluation/Actions Min                            44
# evaluation/Num Paths                             579
# evaluation/Average Returns                        -2.37651
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          297
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           297
# evaluation/env_infos/final/Y_Pos_1 Min           297
# evaluation/env_infos/initial/Y_Pos_1 Mean        297
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         297
# evaluation/env_infos/initial/Y_Pos_1 Min         297
# evaluation/env_infos/Y_Pos_1 Mean                297
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 297
# evaluation/env_infos/Y_Pos_1 Min                 297
# evaluation/env_infos/final/Velocity_y Mean         5.70984
# evaluation/env_infos/final/Velocity_y Std          2.85313
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.70984
# evaluation/env_infos/initial/Velocity_y Std        2.85313
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.7148
# evaluation/env_infos/Velocity_y Std                2.85317
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          355.646
# evaluation/env_infos/final/X_pos_2 Std           135.305
# evaluation/env_infos/final/X_pos_2 Max           580
# evaluation/env_infos/final/X_pos_2 Min           121
# evaluation/env_infos/initial/X_pos_2 Mean        355.646
# evaluation/env_infos/initial/X_pos_2 Std         135.305
# evaluation/env_infos/initial/X_pos_2 Max         580
# evaluation/env_infos/initial/X_pos_2 Min         121
# evaluation/env_infos/X_pos_2 Mean                360.475
# evaluation/env_infos/X_pos_2 Std                 135.053
# evaluation/env_infos/X_pos_2 Max                 580
# evaluation/env_infos/X_pos_2 Min                 121
# time/data storing (s)                              0.000139997
# time/evaluation sampling (s)                       4.29892
# time/exploration sampling (s)                      0.00769283
# time/logging (s)                                   0.054271
# time/saving (s)                                    0.0209207
# time/training (s)                                  5.10551
# time/epoch (s)                                     9.48746
# time/total (s)                                    39.6328
# Epoch                                              3
# ---------------------------------------------  ---------------
# 2019-06-08 21:14:42.423016 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 4 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                                60
# trainer/QF Loss                                    7.41248
# trainer/Y Predictions Mean                         5.45632
# trainer/Y Predictions Std                          4.4257
# trainer/Y Predictions Max                         14.68
# trainer/Y Predictions Min                        -10.1877
# exploration/num steps total                       60
# exploration/num paths total                        8
# exploration/path length Mean                       5
# exploration/path length Std                        3
# exploration/path length Max                        8
# exploration/path length Min                        2
# exploration/Rewards Mean                          -0.1
# exploration/Rewards Std                            3.3
# exploration/Rewards Max                            1
# exploration/Rewards Min                          -10
# exploration/Returns Mean                          -0.5
# exploration/Returns Std                            2.5
# exploration/Returns Max                            2
# exploration/Returns Min                           -3
# exploration/Actions Mean                          73.1
# exploration/Actions Std                           14.577
# exploration/Actions Max                           83
# exploration/Actions Min                           44
# exploration/Num Paths                              2
# exploration/Average Returns                       -0.5
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         345
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          345
# exploration/env_infos/final/Y_Pos_1 Min          345
# exploration/env_infos/initial/Y_Pos_1 Mean       345
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        345
# exploration/env_infos/initial/Y_Pos_1 Min        345
# exploration/env_infos/Y_Pos_1 Mean               345
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                345
# exploration/env_infos/Y_Pos_1 Min                345
# exploration/env_infos/final/Velocity_y Mean        8.5
# exploration/env_infos/final/Velocity_y Std         1.5
# exploration/env_infos/final/Velocity_y Max        10
# exploration/env_infos/final/Velocity_y Min         7
# exploration/env_infos/initial/Velocity_y Mean      8.5
# exploration/env_infos/initial/Velocity_y Std       1.5
# exploration/env_infos/initial/Velocity_y Max      10
# exploration/env_infos/initial/Velocity_y Min       7
# exploration/env_infos/Velocity_y Mean              7.6
# exploration/env_infos/Velocity_y Std               1.2
# exploration/env_infos/Velocity_y Max              10
# exploration/env_infos/Velocity_y Min               7
# exploration/env_infos/final/X_pos_2 Mean         281.5
# exploration/env_infos/final/X_pos_2 Std           93.5
# exploration/env_infos/final/X_pos_2 Max          375
# exploration/env_infos/final/X_pos_2 Min          188
# exploration/env_infos/initial/X_pos_2 Mean       281.5
# exploration/env_infos/initial/X_pos_2 Std         93.5
# exploration/env_infos/initial/X_pos_2 Max        375
# exploration/env_infos/initial/X_pos_2 Min        188
# exploration/env_infos/X_pos_2 Mean               225.4
# exploration/env_infos/X_pos_2 Std                 74.8
# exploration/env_infos/X_pos_2 Max                375
# exploration/env_infos/X_pos_2 Min                188
# evaluation/num steps total                     24973
# evaluation/num paths total                      2706
# evaluation/path length Mean                        9.38722
# evaluation/path length Std                         0.921988
# evaluation/path length Max                        10
# evaluation/path length Min                         8
# evaluation/Rewards Mean                            0.640969
# evaluation/Rewards Std                             1.95459
# evaluation/Rewards Max                             1
# evaluation/Rewards Min                           -10
# evaluation/Returns Mean                            6.01692
# evaluation/Returns Std                             5.99292
# evaluation/Returns Max                            10
# evaluation/Returns Min                            -3
# evaluation/Actions Mean                           38.7435
# evaluation/Actions Std                            30.6339
# evaluation/Actions Max                            80
# evaluation/Actions Min                             9
# evaluation/Num Paths                             532
# evaluation/Average Returns                         6.01692
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          297
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           297
# evaluation/env_infos/final/Y_Pos_1 Min           297
# evaluation/env_infos/initial/Y_Pos_1 Mean        297
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         297
# evaluation/env_infos/initial/Y_Pos_1 Min         297
# evaluation/env_infos/Y_Pos_1 Mean                297
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 297
# evaluation/env_infos/Y_Pos_1 Min                 297
# evaluation/env_infos/final/Velocity_y Mean         5.48684
# evaluation/env_infos/final/Velocity_y Std          2.93248
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.48684
# evaluation/env_infos/initial/Velocity_y Std        2.93248
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.5002
# evaluation/env_infos/Velocity_y Std                2.94199
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          335.519
# evaluation/env_infos/final/X_pos_2 Std           129.587
# evaluation/env_infos/final/X_pos_2 Max           579
# evaluation/env_infos/final/X_pos_2 Min           120
# evaluation/env_infos/initial/X_pos_2 Mean        335.519
# evaluation/env_infos/initial/X_pos_2 Std         129.587
# evaluation/env_infos/initial/X_pos_2 Max         579
# evaluation/env_infos/initial/X_pos_2 Min         120
# evaluation/env_infos/X_pos_2 Mean                342.915
# evaluation/env_infos/X_pos_2 Std                 129.1
# evaluation/env_infos/X_pos_2 Max                 579
# evaluation/env_infos/X_pos_2 Min                 120
# time/data storing (s)                              0.000140407
# time/evaluation sampling (s)                       4.68755
# time/exploration sampling (s)                      0.00722973
# time/logging (s)                                   0.0498334
# time/saving (s)                                    0.0660406
# time/training (s)                                  5.06086
# time/epoch (s)                                     9.87166
# time/total (s)                                    49.6839
# Epoch                                              4
# ---------------------------------------------  ---------------
# 2019-06-08 21:14:51.886498 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 5 finished
# ---------------------------------------------  --------------
# replay_buffer/size                                70
# trainer/QF Loss                                    0.141707
# trainer/Y Predictions Mean                         5.36839
# trainer/Y Predictions Std                          3.56126
# trainer/Y Predictions Max                          9.17634
# trainer/Y Predictions Min                         -9.99465
# exploration/num steps total                       70
# exploration/num paths total                        9
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                           1
# exploration/Rewards Std                            0
# exploration/Rewards Max                            1
# exploration/Rewards Min                            1
# exploration/Returns Mean                          10
# exploration/Returns Std                            0
# exploration/Returns Max                           10
# exploration/Returns Min                           10
# exploration/Actions Mean                          16.1
# exploration/Actions Std                           21.3
# exploration/Actions Max                           80
# exploration/Actions Min                            9
# exploration/Num Paths                              1
# exploration/Average Returns                       10
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         345
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          345
# exploration/env_infos/final/Y_Pos_1 Min          345
# exploration/env_infos/initial/Y_Pos_1 Mean       345
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        345
# exploration/env_infos/initial/Y_Pos_1 Min        345
# exploration/env_infos/Y_Pos_1 Mean               345
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                345
# exploration/env_infos/Y_Pos_1 Min                345
# exploration/env_infos/final/Velocity_y Mean        9
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         9
# exploration/env_infos/final/Velocity_y Min         9
# exploration/env_infos/initial/Velocity_y Mean      9
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       9
# exploration/env_infos/initial/Velocity_y Min       9
# exploration/env_infos/Velocity_y Mean              9
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               9
# exploration/env_infos/Velocity_y Min               9
# exploration/env_infos/final/X_pos_2 Mean         195
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          195
# exploration/env_infos/final/X_pos_2 Min          195
# exploration/env_infos/initial/X_pos_2 Mean       195
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        195
# exploration/env_infos/initial/X_pos_2 Min        195
# exploration/env_infos/X_pos_2 Mean               195
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                195
# exploration/env_infos/X_pos_2 Min                195
# evaluation/num steps total                     29973
# evaluation/num paths total                      3206
# evaluation/path length Mean                       10
# evaluation/path length Std                         0
# evaluation/path length Max                        10
# evaluation/path length Min                        10
# evaluation/Rewards Mean                            1
# evaluation/Rewards Std                             0
# evaluation/Rewards Max                             1
# evaluation/Rewards Min                             1
# evaluation/Returns Mean                           10
# evaluation/Returns Std                             0
# evaluation/Returns Max                            10
# evaluation/Returns Min                            10
# ...
# exploration/env_infos/initial/X_pos_2 Min         423
# exploration/env_infos/X_pos_2 Mean                444.8
# exploration/env_infos/X_pos_2 Std                  43.6
# exploration/env_infos/X_pos_2 Max                 532
# exploration/env_infos/X_pos_2 Min                 423
# evaluation/num steps total                     169874
# evaluation/num paths total                      18405
# evaluation/path length Mean                         8.05806
# evaluation/path length Std                          0.996696
# evaluation/path length Max                         10
# evaluation/path length Min                          7
# evaluation/Rewards Mean                            -0.305645
# evaluation/Rewards Std                              3.55772
# evaluation/Rewards Max                              1
# evaluation/Rewards Min                            -10
# evaluation/Returns Mean                            -2.4629
# evaluation/Returns Std                              2.80959
# evaluation/Returns Max                             10
# evaluation/Returns Min                             -4
# evaluation/Actions Mean                            74.9614
# evaluation/Actions Std                             18.9366
# evaluation/Actions Max                             99
# evaluation/Actions Min                             12
# evaluation/Num Paths                              620
# evaluation/Average Returns                         -2.4629
# evaluation/env_infos/final/actions Mean             0
# evaluation/env_infos/final/actions Std              0
# evaluation/env_infos/final/actions Max              0
# evaluation/env_infos/final/actions Min              0
# evaluation/env_infos/initial/actions Mean           0
# evaluation/env_infos/initial/actions Std            0
# evaluation/env_infos/initial/actions Max            0
# evaluation/env_infos/initial/actions Min            0
# evaluation/env_infos/actions Mean                   0
# evaluation/env_infos/actions Std                    0
# evaluation/env_infos/actions Max                    0
# evaluation/env_infos/actions Min                    0
# evaluation/env_infos/final/Y_Pos_1 Mean           297
# evaluation/env_infos/final/Y_Pos_1 Std              0
# evaluation/env_infos/final/Y_Pos_1 Max            297
# evaluation/env_infos/final/Y_Pos_1 Min            297
# evaluation/env_infos/initial/Y_Pos_1 Mean         297
# evaluation/env_infos/initial/Y_Pos_1 Std            0
# evaluation/env_infos/initial/Y_Pos_1 Max          297
# evaluation/env_infos/initial/Y_Pos_1 Min          297
# evaluation/env_infos/Y_Pos_1 Mean                 297
# evaluation/env_infos/Y_Pos_1 Std                    0
# evaluation/env_infos/Y_Pos_1 Max                  297
# evaluation/env_infos/Y_Pos_1 Min                  297
# evaluation/env_infos/final/Velocity_y Mean          5.52903
# evaluation/env_infos/final/Velocity_y Std           2.91782
# evaluation/env_infos/final/Velocity_y Max          10
# evaluation/env_infos/final/Velocity_y Min           1
# evaluation/env_infos/initial/Velocity_y Mean        5.52903
# evaluation/env_infos/initial/Velocity_y Std         2.91782
# evaluation/env_infos/initial/Velocity_y Max        10
# evaluation/env_infos/initial/Velocity_y Min         1
# evaluation/env_infos/Velocity_y Mean                5.55344
# evaluation/env_infos/Velocity_y Std                 2.9056
# evaluation/env_infos/Velocity_y Max                10
# evaluation/env_infos/Velocity_y Min                 1
# evaluation/env_infos/final/X_pos_2 Mean           353.694
# evaluation/env_infos/final/X_pos_2 Std            137.714
# evaluation/env_infos/final/X_pos_2 Max            580
# evaluation/env_infos/final/X_pos_2 Min            120
# evaluation/env_infos/initial/X_pos_2 Mean         353.694
# evaluation/env_infos/initial/X_pos_2 Std          137.714
# evaluation/env_infos/initial/X_pos_2 Max          580
# evaluation/env_infos/initial/X_pos_2 Min          120
# evaluation/env_infos/X_pos_2 Mean                 342.821
# evaluation/env_infos/X_pos_2 Std                  138.668
# evaluation/env_infos/X_pos_2 Max                  580
# evaluation/env_infos/X_pos_2 Min                  120
# time/data storing (s)                               0.000148618
# time/evaluation sampling (s)                        4.26736
# time/exploration sampling (s)                       0.00768339
# time/logging (s)                                    0.0518484
# time/saving (s)                                     0.00674734
# time/training (s)                                   4.55655
# time/epoch (s)                                      8.89034
# time/total (s)                                    319.883
# Epoch                                              33
# ---------------------------------------------  ----------------
# 2019-06-08 21:19:23.178413 Pacific Daylight Time | [h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\..\data\ddqn-train\ddqn-train_2019_06_08_21_13_54_0000--s-0] Epoch 34 finished
# ---------------------------------------------  ----------------
# replay_buffer/size                                360
# trainer/QF Loss                                 84191.5
# trainer/Y Predictions Mean                        889.529
# trainer/Y Predictions Std                         545.886
# trainer/Y Predictions Max                        3191.28
# trainer/Y Predictions Min                          31.6473
# exploration/num steps total                       360
# exploration/num paths total                        55
# exploration/path length Mean                       10
# exploration/path length Std                         0
# exploration/path length Max                        10
# exploration/path length Min                        10
# exploration/Rewards Mean                            1
# exploration/Rewards Std                             0
# exploration/Rewards Max                             1
# exploration/Rewards Min                             1
# exploration/Returns Mean                           10
# exploration/Returns Std                             0
# exploration/Returns Max                            10
# exploration/Returns Min                            10
# exploration/Actions Mean                           45.6
# exploration/Actions Std                            24.0217
# exploration/Actions Max                            80
# exploration/Actions Min                            14
# exploration/Num Paths                               1
# exploration/Average Returns                        10
# exploration/env_infos/final/actions Mean            0
# exploration/env_infos/final/actions Std             0
# exploration/env_infos/final/actions Max             0
# exploration/env_infos/final/actions Min             0
# exploration/env_infos/initial/actions Mean          0
# exploration/env_infos/initial/actions Std           0
# exploration/env_infos/initial/actions Max           0
# exploration/env_infos/initial/actions Min           0
# exploration/env_infos/actions Mean                  0
# exploration/env_infos/actions Std                   0
# exploration/env_infos/actions Max                   0
# exploration/env_infos/actions Min                   0
# exploration/env_infos/final/Y_Pos_1 Mean          345
# exploration/env_infos/final/Y_Pos_1 Std             0
# exploration/env_infos/final/Y_Pos_1 Max           345
# exploration/env_infos/final/Y_Pos_1 Min           345
# exploration/env_infos/initial/Y_Pos_1 Mean        345
# exploration/env_infos/initial/Y_Pos_1 Std           0
# exploration/env_infos/initial/Y_Pos_1 Max         345
# exploration/env_infos/initial/Y_Pos_1 Min         345
# exploration/env_infos/Y_Pos_1 Mean                345
# exploration/env_infos/Y_Pos_1 Std                   0
# exploration/env_infos/Y_Pos_1 Max                 345
# exploration/env_infos/Y_Pos_1 Min                 345
# exploration/env_infos/final/Velocity_y Mean         1
# exploration/env_infos/final/Velocity_y Std          0
# exploration/env_infos/final/Velocity_y Max          1
# exploration/env_infos/final/Velocity_y Min          1
# exploration/env_infos/initial/Velocity_y Mean       1
# exploration/env_infos/initial/Velocity_y Std        0
# exploration/env_infos/initial/Velocity_y Max        1
# exploration/env_infos/initial/Velocity_y Min        1
# exploration/env_infos/Velocity_y Mean               1
# exploration/env_infos/Velocity_y Std                0
# exploration/env_infos/Velocity_y Max                1
# exploration/env_infos/Velocity_y Min                1
# exploration/env_infos/final/X_pos_2 Mean          265
# exploration/env_infos/final/X_pos_2 Std             0
# exploration/env_infos/final/X_pos_2 Max           265
# exploration/env_infos/final/X_pos_2 Min           265
# exploration/env_infos/initial/X_pos_2 Mean        265
# exploration/env_infos/initial/X_pos_2 Std           0
# exploration/env_infos/initial/X_pos_2 Max         265
# exploration/env_infos/initial/X_pos_2 Min         265
# exploration/env_infos/X_pos_2 Mean                265
# exploration/env_infos/X_pos_2 Std                   0
# exploration/env_infos/X_pos_2 Max                 265
# exploration/env_infos/X_pos_2 Min                 265
# evaluation/num steps total                     174872
# evaluation/num paths total                      18946
# evaluation/path length Mean                         9.23845
# evaluation/path length Std                          0.866548
# evaluation/path length Max                         10
# evaluation/path length Min                          7
# evaluation/Rewards Mean                             0.143858
# evaluation/Rewards Std                              2.94696
# evaluation/Rewards Max                              1
# evaluation/Rewards Min                            -10
# evaluation/Returns Mean                             1.32902
# evaluation/Returns Std                              5.46835
# evaluation/Returns Max                             10
# evaluation/Returns Min                             -4
# evaluation/Actions Mean                            61.9816
# evaluation/Actions Std                             21.4877
# evaluation/Actions Max                             88
# evaluation/Actions Min                              9
# evaluation/Num Paths                              541
# evaluation/Average Returns                          1.32902
# evaluation/env_infos/final/actions Mean             0
# evaluation/env_infos/final/actions Std              0
# evaluation/env_infos/final/actions Max              0
# evaluation/env_infos/final/actions Min              0
# evaluation/env_infos/initial/actions Mean           0
# evaluation/env_infos/initial/actions Std            0
# evaluation/env_infos/initial/actions Max            0
# evaluation/env_infos/initial/actions Min            0
# evaluation/env_infos/actions Mean                   0
# evaluation/env_infos/actions Std                    0
# evaluation/env_infos/actions Max                    0
# evaluation/env_infos/actions Min                    0
# evaluation/env_infos/final/Y_Pos_1 Mean           297
# evaluation/env_infos/final/Y_Pos_1 Std              0
# evaluation/env_infos/final/Y_Pos_1 Max            297
# evaluation/env_infos/final/Y_Pos_1 Min            297
# evaluation/env_infos/initial/Y_Pos_1 Mean         297
# evaluation/env_infos/initial/Y_Pos_1 Std            0
# evaluation/env_infos/initial/Y_Pos_1 Max          297
# evaluation/env_infos/initial/Y_Pos_1 Min          297
# evaluation/env_infos/Y_Pos_1 Mean                 297
# evaluation/env_infos/Y_Pos_1 Std                    0
# evaluation/env_infos/Y_Pos_1 Max                  297
# evaluation/env_infos/Y_Pos_1 Min                  297
# evaluation/env_infos/final/Velocity_y Mean          5.56007
# evaluation/env_infos/final/Velocity_y Std           2.917
# evaluation/env_infos/final/Velocity_y Max          10
# evaluation/env_infos/final/Velocity_y Min           1
# evaluation/env_infos/initial/Velocity_y Mean        5.56007
# evaluation/env_infos/initial/Velocity_y Std         2.917
# evaluation/env_infos/initial/Velocity_y Max        10
# evaluation/env_infos/initial/Velocity_y Min         1
# evaluation/env_infos/Velocity_y Mean                5.58643
# evaluation/env_infos/Velocity_y Std                 2.91847
# evaluation/env_infos/Velocity_y Max                10
# evaluation/env_infos/Velocity_y Min                 1
# evaluation/env_infos/final/X_pos_2 Mean           342.9
# evaluation/env_infos/final/X_pos_2 Std            131.146
# evaluation/env_infos/final/X_pos_2 Max            580
# evaluation/env_infos/final/X_pos_2 Min            120
# evaluation/env_infos/initial/X_pos_2 Mean         342.9
# evaluation/env_infos/initial/X_pos_2 Std          131.146
# evaluation/env_infos/initial/X_pos_2 Max          580
# evaluation/env_infos/initial/X_pos_2 Min          120
# evaluation/env_infos/X_pos_2 Mean                 343.403
# evaluation/env_infos/X_pos_2 Std                  130.545
# evaluation/env_infos/X_pos_2 Max                  580
# evaluation/env_infos/X_pos_2 Min                  120
# time/data storing (s)                               0.000136302
# time/evaluation sampling (s)                        4.01417
# time/exploration sampling (s)                       0.00706264
# time/logging (s)                                    0.115466
# time/saving (s)                                     0.018108
# time/training (s)                                   6.23212
# time/epoch (s)                                     10.3871
# time/total (s)                                    330.465
# Epoch                                              34
# ---------------------------------------------  ----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c1ea540a4c0c> in <module>()
#      22     setup_logger('ddqn-train', variant=variant)
#      23     # ptu.set_gpu_mode(True)  # optionally set the GPU (default=False)
# ---> 24     experiment(variant)
#
# <ipython-input-1-46ac0e71559b> in experiment(variant)
#      65     )
#      66     algorithm.to(ptu.device)
# ---> 67     algorithm.train()
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\core\rl_algorithm.py in train(self, start_epoch)
#      44     def train(self, start_epoch=0):
#      45         self._start_epoch = start_epoch
# ---> 46         self._train()
#      47
#      48     def _train(self):
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\core\batch_rl_algorithm.py in _train(self)
#      59                 self.max_path_length,
#      60                 self.num_eval_steps_per_epoch,
# ---> 61                 discard_incomplete_paths=True,
#      62             )
#      63             gt.stamp('evaluation sampling')
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\samplers\data_collector\path_collector.py in collect_new_paths(self, max_path_length, num_steps, discard_incomplete_paths)
#      44                 self._env,
#      45                 self._policy,
# ---> 46                 max_path_length=max_path_length_this_loop,
#      47             )
#      48             path_len = len(path['actions'])
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\samplers\rollout_functions.py in rollout(env, agent, max_path_length, render, render_kwargs)
#     110         env.render(**render_kwargs)
#     111     while path_length < max_path_length:
# --> 112         a, agent_info = agent.get_action(o)
#     113         next_o, r, d, env_info = env.step(a)
#     114         observations.append(o)
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\policies\argmax.py in get_action(self, obs)
#      16     def get_action(self, obs):
#      17         obs = np.expand_dims(obs, axis=0)
# ---> 18         obs = ptu.from_numpy(obs).float()
#      19         q_values = self.qf(obs).squeeze(0)
#      20         q_values_np = ptu.get_numpy(q_values)
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\torch\pytorch_util.py in from_numpy(*args, **kwargs)
#      75
#      76 def from_numpy(*args, **kwargs):
# ---> 77     return torch.from_numpy(*args, **kwargs).float().to(device)
#      78
#      79
#
# KeyboardInterrupt:

# %%
env = gym.make('Physics_RL-v0')
env.reset()
# Out:
# (10, 174, 421, 10)

# %%
#env.observation_space.low.size
env.step(10)
# Out:
# ((180, 174, 421, 95),
#  0,
#  False,
#  {'Velocity_y': 5,
#   'X_pos_2': 421,
#   'Y_Pos_1': 278,
#   'actions': [10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10]})
