# %%
import gym
import gym_Physics_RL
from torch import nn as nn

from rlkit.exploration_strategies.base import PolicyWrappedWithExplorationStrategy
from rlkit.exploration_strategies.epsilon_greedy import EpsilonGreedy
from rlkit.policies.argmax import ArgmaxDiscretePolicy
from rlkit.torch.dqn.double_dqn import DoubleDQNTrainer
from rlkit.torch.networks import Mlp
import rlkit.torch.pytorch_util as ptu
from rlkit.data_management.env_replay_buffer import EnvReplayBuffer
from rlkit.launchers.launcher_util import setup_logger
from rlkit.samplers.data_collector import MdpPathCollector
from rlkit.torch.torch_rl_algorithm import TorchBatchRLAlgorithm


def experiment(variant):
    expl_env = gym.make('Physics_RL-v0')
    eval_env = gym.make('Physics_RL-v0')
    obs_dim = expl_env.observation_space.low.size
    action_dim = eval_env.action_space.n

    qf = Mlp(
        hidden_sizes=[32, 32],
        input_size=obs_dim,
        output_size=action_dim,
    )
    target_qf = Mlp(
        hidden_sizes=[32, 32],
        input_size=obs_dim,
        output_size=action_dim,
    )
    qf_criterion = nn.MSELoss()
    eval_policy = ArgmaxDiscretePolicy(qf)
    expl_policy = PolicyWrappedWithExplorationStrategy(
        EpsilonGreedy(expl_env.action_space),
        eval_policy,
    )
    eval_path_collector = MdpPathCollector(
        eval_env,
        eval_policy,
    )
    expl_path_collector = MdpPathCollector(
        expl_env,
        expl_policy,
    )
    trainer = DoubleDQNTrainer(
        qf=qf,
        target_qf=target_qf,
        qf_criterion=qf_criterion,
        **variant['trainer_kwargs']
    )
    replay_buffer = EnvReplayBuffer(
        variant['replay_buffer_size'],
        expl_env,
    )
    algorithm = TorchBatchRLAlgorithm(
        trainer=trainer,
        exploration_env=expl_env,
        evaluation_env=eval_env,
        exploration_data_collector=expl_path_collector,
        evaluation_data_collector=eval_path_collector,
        replay_buffer=replay_buffer,
        **variant['algorithm_kwargs']
    )
    algorithm.to(ptu.device)
    algorithm.train()
# Out:
# doodad not detected

# %%
if __name__ == "__main__":
    # noinspection PyTypeChecker
    variant = dict(
        algorithm="DDQN",
        version="normal",
        layer_size=256,
        replay_buffer_size=int(1E6),
        algorithm_kwargs=dict(
            num_epochs=3000,
            num_eval_steps_per_epoch=5000,
            num_trains_per_train_loop=1000,
            num_expl_steps_per_train_loop=10,
            min_num_steps_before_training=1000,
            max_path_length=100,
            batch_size=16,
        ),
        trainer_kwargs=dict(
            discount=0.99,
            learning_rate=3E-5,
        ),
    )
    setup_logger('./ddqn-train', variant=variant)
    # ptu.set_gpu_mode(True)  # optionally set the GPU (default=False)
    experiment(variant)
# Out:
# 2019-06-09 01:34:02.724874 Pacific Daylight Time | Variant:
# 2019-06-09 01:34:02.727877 Pacific Daylight Time | {
#   "algorithm": "DDQN",
#   "version": "normal",
#   "layer_size": 256,
#   "replay_buffer_size": 1000000,
#   "algorithm_kwargs": {
#     "num_epochs": 3000,
#     "num_eval_steps_per_epoch": 5000,
#     "num_trains_per_train_loop": 1000,
#     "num_expl_steps_per_train_loop": 10,
#     "min_num_steps_before_training": 1000,
#     "max_path_length": 100,
#     "batch_size": 16
#   },
#   "trainer_kwargs": {
#     "discount": 0.99,
#     "learning_rate": 3e-05
#   }
# }
# 2019-06-09 01:34:09.217871 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 0 finished
# ---------------------------------------------  --------------
# replay_buffer/size                             1010
# trainer/QF Loss                                   1.97087
# trainer/Y Predictions Mean                        0.226821
# trainer/Y Predictions Std                         0.082281
# trainer/Y Predictions Max                         0.34163
# trainer/Y Predictions Min                         0.00293777
# exploration/num steps total                    1010
# exploration/num paths total                      19
# exploration/path length Mean                     10
# exploration/path length Std                       0
# exploration/path length Max                      10
# exploration/path length Min                      10
# exploration/Rewards Mean                         -1
# exploration/Rewards Std                           0
# exploration/Rewards Max                          -1
# exploration/Rewards Min                          -1
# exploration/Returns Mean                        -10
# exploration/Returns Std                           0
# exploration/Returns Max                         -10
# exploration/Returns Min                         -10
# exploration/Actions Mean                         12.7
# exploration/Actions Std                          29.3191
# exploration/Actions Max                          99
# exploration/Actions Min                           1
# exploration/Num Paths                             1
# exploration/Average Returns                     -10
# exploration/env_infos/final/actions Mean          0
# exploration/env_infos/final/actions Std           0
# exploration/env_infos/final/actions Max           0
# exploration/env_infos/final/actions Min           0
# exploration/env_infos/initial/actions Mean        0
# exploration/env_infos/initial/actions Std         0
# exploration/env_infos/initial/actions Max         0
# exploration/env_infos/initial/actions Min         0
# exploration/env_infos/actions Mean                0
# exploration/env_infos/actions Std                 0
# exploration/env_infos/actions Max                 0
# exploration/env_infos/actions Min                 0
# exploration/env_infos/final/Y_Pos_1 Mean        198
# exploration/env_infos/final/Y_Pos_1 Std           0
# exploration/env_infos/final/Y_Pos_1 Max         198
# exploration/env_infos/final/Y_Pos_1 Min         198
# exploration/env_infos/initial/Y_Pos_1 Mean      198
# exploration/env_infos/initial/Y_Pos_1 Std         0
# exploration/env_infos/initial/Y_Pos_1 Max       198
# exploration/env_infos/initial/Y_Pos_1 Min       198
# exploration/env_infos/Y_Pos_1 Mean              198
# exploration/env_infos/Y_Pos_1 Std                 0
# exploration/env_infos/Y_Pos_1 Max               198
# exploration/env_infos/Y_Pos_1 Min               198
# exploration/env_infos/final/Velocity_y Mean       3
# exploration/env_infos/final/Velocity_y Std        0
# exploration/env_infos/final/Velocity_y Max        3
# exploration/env_infos/final/Velocity_y Min        3
# exploration/env_infos/initial/Velocity_y Mean     3
# exploration/env_infos/initial/Velocity_y Std      0
# exploration/env_infos/initial/Velocity_y Max      3
# exploration/env_infos/initial/Velocity_y Min      3
# exploration/env_infos/Velocity_y Mean             3
# exploration/env_infos/Velocity_y Std              0
# exploration/env_infos/Velocity_y Max              3
# exploration/env_infos/Velocity_y Min              3
# exploration/env_infos/final/X_pos_2 Mean        399
# exploration/env_infos/final/X_pos_2 Std           0
# exploration/env_infos/final/X_pos_2 Max         399
# exploration/env_infos/final/X_pos_2 Min         399
# exploration/env_infos/initial/X_pos_2 Mean      399
# exploration/env_infos/initial/X_pos_2 Std         0
# exploration/env_infos/initial/X_pos_2 Max       399
# exploration/env_infos/initial/X_pos_2 Min       399
# exploration/env_infos/X_pos_2 Mean              399
# exploration/env_infos/X_pos_2 Std                 0
# exploration/env_infos/X_pos_2 Max               399
# exploration/env_infos/X_pos_2 Min               399
# evaluation/num steps total                     4992
# evaluation/num paths total                       70
# evaluation/path length Mean                      71.3143
# evaluation/path length Std                       30.3981
# evaluation/path length Max                      100
# evaluation/path length Min                        9
# evaluation/Rewards Mean                          -1.1228
# evaluation/Rewards Std                            1.86974
# evaluation/Rewards Max                           20
# evaluation/Rewards Min                          -20
# evaluation/Returns Mean                         -80.0714
# evaluation/Returns Std                           31.5021
# evaluation/Returns Max                            2
# evaluation/Returns Min                         -118
# evaluation/Actions Mean                           6.51342
# evaluation/Actions Std                           18.8566
# evaluation/Actions Max                           98
# evaluation/Actions Min                            1
# evaluation/Num Paths                             70
# evaluation/Average Returns                      -80.0714
# evaluation/env_infos/final/actions Mean           0
# evaluation/env_infos/final/actions Std            0
# evaluation/env_infos/final/actions Max            0
# evaluation/env_infos/final/actions Min            0
# evaluation/env_infos/initial/actions Mean         0
# evaluation/env_infos/initial/actions Std          0
# evaluation/env_infos/initial/actions Max          0
# evaluation/env_infos/initial/actions Min          0
# evaluation/env_infos/actions Mean                 0
# evaluation/env_infos/actions Std                  0
# evaluation/env_infos/actions Max                  0
# evaluation/env_infos/actions Min                  0
# evaluation/env_infos/final/Y_Pos_1 Mean         149
# evaluation/env_infos/final/Y_Pos_1 Std            0
# evaluation/env_infos/final/Y_Pos_1 Max          149
# evaluation/env_infos/final/Y_Pos_1 Min          149
# evaluation/env_infos/initial/Y_Pos_1 Mean       149
# evaluation/env_infos/initial/Y_Pos_1 Std          0
# evaluation/env_infos/initial/Y_Pos_1 Max        149
# evaluation/env_infos/initial/Y_Pos_1 Min        149
# evaluation/env_infos/Y_Pos_1 Mean               149
# evaluation/env_infos/Y_Pos_1 Std                  0
# evaluation/env_infos/Y_Pos_1 Max                149
# evaluation/env_infos/Y_Pos_1 Min                149
# evaluation/env_infos/final/Velocity_y Mean        5.95714
# evaluation/env_infos/final/Velocity_y Std         2.84573
# evaluation/env_infos/final/Velocity_y Max        10
# evaluation/env_infos/final/Velocity_y Min         1
# evaluation/env_infos/initial/Velocity_y Mean      5.95714
# evaluation/env_infos/initial/Velocity_y Std       2.84573
# evaluation/env_infos/initial/Velocity_y Max      10
# evaluation/env_infos/initial/Velocity_y Min       1
# evaluation/env_infos/Velocity_y Mean              5.28065
# evaluation/env_infos/Velocity_y Std               2.68333
# evaluation/env_infos/Velocity_y Max              10
# evaluation/env_infos/Velocity_y Min               1
# evaluation/env_infos/final/X_pos_2 Mean         337.143
# evaluation/env_infos/final/X_pos_2 Std          136.524
# evaluation/env_infos/final/X_pos_2 Max          575
# evaluation/env_infos/final/X_pos_2 Min          133
# evaluation/env_infos/initial/X_pos_2 Mean       337.143
# evaluation/env_infos/initial/X_pos_2 Std        136.524
# evaluation/env_infos/initial/X_pos_2 Max        575
# evaluation/env_infos/initial/X_pos_2 Min        133
# evaluation/env_infos/X_pos_2 Mean               353.638
# evaluation/env_infos/X_pos_2 Std                130.414
# evaluation/env_infos/X_pos_2 Max                575
# evaluation/env_infos/X_pos_2 Min                133
# time/data storing (s)                             0.000129322
# time/evaluation sampling (s)                      3.7404
# time/exploration sampling (s)                     0.00771993
# time/logging (s)                                  0.040161
# time/saving (s)                                   0.00782462
# time/training (s)                                 1.79598
# time/epoch (s)                                    5.59221
# time/total (s)                                    8.28735
# Epoch                                             0
# ---------------------------------------------  --------------
# 2019-06-09 01:34:15.564566 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 1 finished
# ---------------------------------------------  -------------
# replay_buffer/size                             1020
# trainer/QF Loss                                   0.117002
# trainer/Y Predictions Mean                       -0.985309
# trainer/Y Predictions Std                         0.318238
# trainer/Y Predictions Max                        -0.336898
# trainer/Y Predictions Min                        -1.68634
# exploration/num steps total                    1020
# exploration/num paths total                      20
# exploration/path length Mean                     10
# exploration/path length Std                       0
# exploration/path length Max                      10
# exploration/path length Min                      10
# exploration/Rewards Mean                         -1
# exploration/Rewards Std                           0
# exploration/Rewards Max                          -1
# exploration/Rewards Min                          -1
# exploration/Returns Mean                        -10
# exploration/Returns Std                           0
# exploration/Returns Max                         -10
# exploration/Returns Min                         -10
# exploration/Actions Mean                         56.7
# exploration/Actions Std                          24.9882
# exploration/Actions Max                          86
# exploration/Actions Min                          33
# exploration/Num Paths                             1
# exploration/Average Returns                     -10
# exploration/env_infos/final/actions Mean          0
# exploration/env_infos/final/actions Std           0
# exploration/env_infos/final/actions Max           0
# exploration/env_infos/final/actions Min           0
# exploration/env_infos/initial/actions Mean        0
# exploration/env_infos/initial/actions Std         0
# exploration/env_infos/initial/actions Max         0
# exploration/env_infos/initial/actions Min         0
# exploration/env_infos/actions Mean                0
# exploration/env_infos/actions Std                 0
# exploration/env_infos/actions Max                 0
# exploration/env_infos/actions Min                 0
# exploration/env_infos/final/Y_Pos_1 Mean        198
# exploration/env_infos/final/Y_Pos_1 Std           0
# exploration/env_infos/final/Y_Pos_1 Max         198
# exploration/env_infos/final/Y_Pos_1 Min         198
# exploration/env_infos/initial/Y_Pos_1 Mean      198
# exploration/env_infos/initial/Y_Pos_1 Std         0
# exploration/env_infos/initial/Y_Pos_1 Max       198
# exploration/env_infos/initial/Y_Pos_1 Min       198
# exploration/env_infos/Y_Pos_1 Mean              198
# exploration/env_infos/Y_Pos_1 Std                 0
# exploration/env_infos/Y_Pos_1 Max               198
# exploration/env_infos/Y_Pos_1 Min               198
# exploration/env_infos/final/Velocity_y Mean       1
# exploration/env_infos/final/Velocity_y Std        0
# exploration/env_infos/final/Velocity_y Max        1
# exploration/env_infos/final/Velocity_y Min        1
# exploration/env_infos/initial/Velocity_y Mean     1
# exploration/env_infos/initial/Velocity_y Std      0
# exploration/env_infos/initial/Velocity_y Max      1
# exploration/env_infos/initial/Velocity_y Min      1
# exploration/env_infos/Velocity_y Mean             1
# exploration/env_infos/Velocity_y Std              0
# exploration/env_infos/Velocity_y Max              1
# exploration/env_infos/Velocity_y Min              1
# exploration/env_infos/final/X_pos_2 Mean        499
# exploration/env_infos/final/X_pos_2 Std           0
# exploration/env_infos/final/X_pos_2 Max         499
# exploration/env_infos/final/X_pos_2 Min         499
# exploration/env_infos/initial/X_pos_2 Mean      499
# exploration/env_infos/initial/X_pos_2 Std         0
# exploration/env_infos/initial/X_pos_2 Max       499
# exploration/env_infos/initial/X_pos_2 Min       499
# exploration/env_infos/X_pos_2 Mean              499
# exploration/env_infos/X_pos_2 Std                 0
# exploration/env_infos/X_pos_2 Max               499
# exploration/env_infos/X_pos_2 Min               499
# evaluation/num steps total                     9992
# evaluation/num paths total                      436
# evaluation/path length Mean                      13.6612
# evaluation/path length Std                        8.02183
# evaluation/path length Max                       71
# evaluation/path length Min                        7
# evaluation/Rewards Mean                          -2.3588
# evaluation/Rewards Std                            4.96416
# evaluation/Rewards Max                           20
# evaluation/Rewards Min                          -20
# evaluation/Returns Mean                         -32.224
# evaluation/Returns Std                            8.71116
# evaluation/Returns Max                            3
# evaluation/Returns Min                          -90
# evaluation/Actions Mean                          44.1108
# evaluation/Actions Std                           30.9416
# evaluation/Actions Max                           95
# evaluation/Actions Min                            2
# evaluation/Num Paths                            366
# evaluation/Average Returns                      -32.224
# evaluation/env_infos/final/actions Mean           0
# evaluation/env_infos/final/actions Std            0
# evaluation/env_infos/final/actions Max            0
# evaluation/env_infos/final/actions Min            0
# evaluation/env_infos/initial/actions Mean         0
# evaluation/env_infos/initial/actions Std          0
# evaluation/env_infos/initial/actions Max          0
# evaluation/env_infos/initial/actions Min          0
# evaluation/env_infos/actions Mean                 0
# evaluation/env_infos/actions Std                  0
# evaluation/env_infos/actions Max                  0
# evaluation/env_infos/actions Min                  0
# evaluation/env_infos/final/Y_Pos_1 Mean         149
# evaluation/env_infos/final/Y_Pos_1 Std            0
# evaluation/env_infos/final/Y_Pos_1 Max          149
# evaluation/env_infos/final/Y_Pos_1 Min          149
# evaluation/env_infos/initial/Y_Pos_1 Mean       149
# evaluation/env_infos/initial/Y_Pos_1 Std          0
# evaluation/env_infos/initial/Y_Pos_1 Max        149
# evaluation/env_infos/initial/Y_Pos_1 Min        149
# evaluation/env_infos/Y_Pos_1 Mean               149
# evaluation/env_infos/Y_Pos_1 Std                  0
# evaluation/env_infos/Y_Pos_1 Max                149
# evaluation/env_infos/Y_Pos_1 Min                149
# evaluation/env_infos/final/Velocity_y Mean        5.35792
# evaluation/env_infos/final/Velocity_y Std         2.91693
# evaluation/env_infos/final/Velocity_y Max        10
# evaluation/env_infos/final/Velocity_y Min         1
# evaluation/env_infos/initial/Velocity_y Mean      5.35792
# evaluation/env_infos/initial/Velocity_y Std       2.91693
# evaluation/env_infos/initial/Velocity_y Max      10
# evaluation/env_infos/initial/Velocity_y Min       1
# evaluation/env_infos/Velocity_y Mean              5.0522
# evaluation/env_infos/Velocity_y Std               2.8475
# evaluation/env_infos/Velocity_y Max              10
# evaluation/env_infos/Velocity_y Min               1
# evaluation/env_infos/final/X_pos_2 Mean         343.557
# evaluation/env_infos/final/X_pos_2 Std          127.138
# evaluation/env_infos/final/X_pos_2 Max          580
# evaluation/env_infos/final/X_pos_2 Min          123
# evaluation/env_infos/initial/X_pos_2 Mean       343.557
# evaluation/env_infos/initial/X_pos_2 Std        127.138
# evaluation/env_infos/initial/X_pos_2 Max        580
# evaluation/env_infos/initial/X_pos_2 Min        123
# evaluation/env_infos/X_pos_2 Mean               335.461
# evaluation/env_infos/X_pos_2 Std                133.707
# evaluation/env_infos/X_pos_2 Max                580
# evaluation/env_infos/X_pos_2 Min                123
# time/data storing (s)                             0.00015765
# time/evaluation sampling (s)                      3.85624
# time/exploration sampling (s)                     0.0073492
# time/logging (s)                                  0.0465634
# time/saving (s)                                   0.00693086
# time/training (s)                                 2.25099
# time/epoch (s)                                    6.16823
# time/total (s)                                   14.6384
# Epoch                                             1
# ---------------------------------------------  -------------
# 2019-06-09 01:34:22.410624 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 2 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                              1030
# trainer/QF Loss                                   37.4872
# trainer/Y Predictions Mean                        -1.0617
# trainer/Y Predictions Std                          0.857234
# trainer/Y Predictions Max                         -0.384287
# trainer/Y Predictions Min                         -4.25903
# exploration/num steps total                     1030
# exploration/num paths total                       21
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                          -1
# exploration/Rewards Std                            0
# exploration/Rewards Max                           -1
# exploration/Rewards Min                           -1
# exploration/Returns Mean                         -10
# exploration/Returns Std                            0
# exploration/Returns Max                          -10
# exploration/Returns Min                          -10
# exploration/Actions Mean                          14.1
# exploration/Actions Std                            9.88383
# exploration/Actions Max                           23
# exploration/Actions Min                            2
# exploration/Num Paths                              1
# exploration/Average Returns                      -10
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         198
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          198
# exploration/env_infos/final/Y_Pos_1 Min          198
# exploration/env_infos/initial/Y_Pos_1 Mean       198
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        198
# exploration/env_infos/initial/Y_Pos_1 Min        198
# exploration/env_infos/Y_Pos_1 Mean               198
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                198
# exploration/env_infos/Y_Pos_1 Min                198
# exploration/env_infos/final/Velocity_y Mean        9
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         9
# exploration/env_infos/final/Velocity_y Min         9
# exploration/env_infos/initial/Velocity_y Mean      9
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       9
# exploration/env_infos/initial/Velocity_y Min       9
# exploration/env_infos/Velocity_y Mean              9
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               9
# exploration/env_infos/Velocity_y Min               9
# exploration/env_infos/final/X_pos_2 Mean         475
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          475
# exploration/env_infos/final/X_pos_2 Min          475
# exploration/env_infos/initial/X_pos_2 Mean       475
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        475
# exploration/env_infos/initial/X_pos_2 Min        475
# exploration/env_infos/X_pos_2 Mean               475
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                475
# exploration/env_infos/X_pos_2 Min                475
# evaluation/num steps total                     14928
# evaluation/num paths total                       499
# evaluation/path length Mean                       78.3492
# evaluation/path length Std                        25.356
# evaluation/path length Max                       100
# evaluation/path length Min                        15
# evaluation/Rewards Mean                           -1.12581
# evaluation/Rewards Std                             1.69856
# evaluation/Rewards Max                            20
# evaluation/Rewards Min                           -20
# evaluation/Returns Mean                          -88.2063
# evaluation/Returns Std                            24.4041
# evaluation/Returns Max                            -3
# evaluation/Returns Min                          -118
# evaluation/Actions Mean                            4.26864
# evaluation/Actions Std                            10.3682
# evaluation/Actions Max                            95
# evaluation/Actions Min                             2
# evaluation/Num Paths                              63
# evaluation/Average Returns                       -88.2063
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          149
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           149
# evaluation/env_infos/final/Y_Pos_1 Min           149
# evaluation/env_infos/initial/Y_Pos_1 Mean        149
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         149
# evaluation/env_infos/initial/Y_Pos_1 Min         149
# evaluation/env_infos/Y_Pos_1 Mean                149
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 149
# evaluation/env_infos/Y_Pos_1 Min                 149
# evaluation/env_infos/final/Velocity_y Mean         5.74603
# evaluation/env_infos/final/Velocity_y Std          2.73117
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.74603
# evaluation/env_infos/initial/Velocity_y Std        2.73117
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.39364
# evaluation/env_infos/Velocity_y Std                2.65058
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          380.365
# evaluation/env_infos/final/X_pos_2 Std           137.547
# evaluation/env_infos/final/X_pos_2 Max           580
# evaluation/env_infos/final/X_pos_2 Min           121
# evaluation/env_infos/initial/X_pos_2 Mean        380.365
# evaluation/env_infos/initial/X_pos_2 Std         137.547
# evaluation/env_infos/initial/X_pos_2 Max         580
# evaluation/env_infos/initial/X_pos_2 Min         121
# evaluation/env_infos/X_pos_2 Mean                401.086
# evaluation/env_infos/X_pos_2 Std                 127.393
# evaluation/env_infos/X_pos_2 Max                 580
# evaluation/env_infos/X_pos_2 Min                 121
# time/data storing (s)                              0.000145334
# time/evaluation sampling (s)                       4.28354
# time/exploration sampling (s)                      0.0084273
# time/logging (s)                                   0.0348846
# time/saving (s)                                    0.00872289
# time/training (s)                                  2.26127
# time/epoch (s)                                     6.59699
# time/total (s)                                    21.4715
# Epoch                                              2
# ---------------------------------------------  ---------------
# 2019-06-09 01:34:28.870639 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 3 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                              1040
# trainer/QF Loss                                    1.30306
# trainer/Y Predictions Mean                        -0.953771
# trainer/Y Predictions Std                          1.09939
# trainer/Y Predictions Max                          0.119901
# trainer/Y Predictions Min                         -5.09211
# exploration/num steps total                     1040
# exploration/num paths total                       22
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                          -1
# exploration/Rewards Std                            0
# exploration/Rewards Max                           -1
# exploration/Rewards Min                           -1
# exploration/Returns Mean                         -10
# exploration/Returns Std                            0
# exploration/Returns Max                          -10
# exploration/Returns Min                          -10
# exploration/Actions Mean                          16.1
# exploration/Actions Std                           21.7184
# exploration/Actions Max                           79
# exploration/Actions Min                            7
# exploration/Num Paths                              1
# exploration/Average Returns                      -10
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         198
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          198
# exploration/env_infos/final/Y_Pos_1 Min          198
# exploration/env_infos/initial/Y_Pos_1 Mean       198
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        198
# exploration/env_infos/initial/Y_Pos_1 Min        198
# exploration/env_infos/Y_Pos_1 Mean               198
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                198
# exploration/env_infos/Y_Pos_1 Min                198
# exploration/env_infos/final/Velocity_y Mean       10
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max        10
# exploration/env_infos/final/Velocity_y Min        10
# exploration/env_infos/initial/Velocity_y Mean     10
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max      10
# exploration/env_infos/initial/Velocity_y Min      10
# exploration/env_infos/Velocity_y Mean             10
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max              10
# exploration/env_infos/Velocity_y Min              10
# exploration/env_infos/final/X_pos_2 Mean         387
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          387
# exploration/env_infos/final/X_pos_2 Min          387
# exploration/env_infos/initial/X_pos_2 Mean       387
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        387
# exploration/env_infos/initial/X_pos_2 Min        387
# exploration/env_infos/X_pos_2 Mean               387
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                387
# exploration/env_infos/X_pos_2 Min                387
# evaluation/num steps total                     19924
# evaluation/num paths total                       722
# evaluation/path length Mean                       22.4036
# evaluation/path length Std                         6.07268
# evaluation/path length Max                        40
# evaluation/path length Min                        10
# evaluation/Rewards Mean                           -1.80805
# evaluation/Rewards Std                             3.94216
# evaluation/Rewards Max                            20
# evaluation/Rewards Min                           -20
# evaluation/Returns Mean                          -40.5067
# evaluation/Returns Std                             8.75315
# evaluation/Returns Max                             7
# evaluation/Returns Min                           -59
# evaluation/Actions Mean                           26.7484
# evaluation/Actions Std                            17.1081
# evaluation/Actions Max                            95
# evaluation/Actions Min                             7
# evaluation/Num Paths                             223
# evaluation/Average Returns                       -40.5067
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          149
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           149
# evaluation/env_infos/final/Y_Pos_1 Min           149
# evaluation/env_infos/initial/Y_Pos_1 Mean        149
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         149
# evaluation/env_infos/initial/Y_Pos_1 Min         149
# evaluation/env_infos/Y_Pos_1 Mean                149
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 149
# evaluation/env_infos/Y_Pos_1 Min                 149
# evaluation/env_infos/final/Velocity_y Mean         5.84305
# evaluation/env_infos/final/Velocity_y Std          2.8201
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.84305
# evaluation/env_infos/initial/Velocity_y Std        2.8201
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.72898
# evaluation/env_infos/Velocity_y Std                2.81776
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          331.561
# evaluation/env_infos/final/X_pos_2 Std           135.3
# evaluation/env_infos/final/X_pos_2 Max           578
# evaluation/env_infos/final/X_pos_2 Min           121
# evaluation/env_infos/initial/X_pos_2 Mean        331.561
# evaluation/env_infos/initial/X_pos_2 Std         135.3
# evaluation/env_infos/initial/X_pos_2 Max         578
# evaluation/env_infos/initial/X_pos_2 Min         121
# evaluation/env_infos/X_pos_2 Mean                357.422
# evaluation/env_infos/X_pos_2 Std                 132.465
# evaluation/env_infos/X_pos_2 Max                 578
# evaluation/env_infos/X_pos_2 Min                 121
# time/data storing (s)                              0.000144513
# time/evaluation sampling (s)                       4.26719
# time/exploration sampling (s)                      0.0081703
# time/logging (s)                                   0.0350858
# time/saving (s)                                    0.00977102
# time/training (s)                                  1.95071
# time/epoch (s)                                     6.27107
# time/total (s)                                    27.9313
# Epoch                                              3
# ---------------------------------------------  ---------------
# 2019-06-09 01:34:35.794650 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 4 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                              1050
# trainer/QF Loss                                    0.323528
# trainer/Y Predictions Mean                        -0.665839
# trainer/Y Predictions Std                          0.367829
# trainer/Y Predictions Max                          0.510256
# trainer/Y Predictions Min                         -1.32277
# exploration/num steps total                     1050
# exploration/num paths total                       23
# exploration/path length Mean                      10
# exploration/path length Std                        0
# exploration/path length Max                       10
# exploration/path length Min                       10
# exploration/Rewards Mean                          -1
# exploration/Rewards Std                            0
# exploration/Rewards Max                           -1
# exploration/Rewards Min                           -1
# exploration/Returns Mean                         -10
# exploration/Returns Std                            0
# exploration/Returns Max                          -10
# exploration/Returns Min                          -10
# exploration/Actions Mean                          44.4
# exploration/Actions Std                           26.7328
# exploration/Actions Max                           95
# exploration/Actions Min                           13
# exploration/Num Paths                              1
# exploration/Average Returns                      -10
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         198
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          198
# exploration/env_infos/final/Y_Pos_1 Min          198
# exploration/env_infos/initial/Y_Pos_1 Mean       198
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        198
# exploration/env_infos/initial/Y_Pos_1 Min        198
# exploration/env_infos/Y_Pos_1 Mean               198
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                198
# exploration/env_infos/Y_Pos_1 Min                198
# exploration/env_infos/final/Velocity_y Mean        3
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         3
# exploration/env_infos/final/Velocity_y Min         3
# exploration/env_infos/initial/Velocity_y Mean      3
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       3
# exploration/env_infos/initial/Velocity_y Min       3
# exploration/env_infos/Velocity_y Mean              3
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               3
# exploration/env_infos/Velocity_y Min               3
# exploration/env_infos/final/X_pos_2 Mean         197
# exploration/env_infos/final/X_pos_2 Std            0
# exploration/env_infos/final/X_pos_2 Max          197
# exploration/env_infos/final/X_pos_2 Min          197
# exploration/env_infos/initial/X_pos_2 Mean       197
# exploration/env_infos/initial/X_pos_2 Std          0
# exploration/env_infos/initial/X_pos_2 Max        197
# exploration/env_infos/initial/X_pos_2 Min        197
# exploration/env_infos/X_pos_2 Mean               197
# exploration/env_infos/X_pos_2 Std                  0
# exploration/env_infos/X_pos_2 Max                197
# exploration/env_infos/X_pos_2 Min                197
# evaluation/num steps total                     24918
# evaluation/num paths total                      1313
# evaluation/path length Mean                        8.45008
# evaluation/path length Std                         2.35161
# evaluation/path length Max                        15
# evaluation/path length Min                         7
# evaluation/Rewards Mean                           -3.23248
# evaluation/Rewards Std                             6.14569
# evaluation/Rewards Max                            20
# evaluation/Rewards Min                           -20
# evaluation/Returns Mean                          -27.3147
# evaluation/Returns Std                             3.15678
# evaluation/Returns Max                            10
# evaluation/Returns Min                           -34
# evaluation/Actions Mean                           75.7058
# evaluation/Actions Std                            26.6492
# evaluation/Actions Max                            95
# evaluation/Actions Min                            30
# evaluation/Num Paths                             591
# evaluation/Average Returns                       -27.3147
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# evaluation/env_infos/initial/actions Std           0
# evaluation/env_infos/initial/actions Max           0
# evaluation/env_infos/initial/actions Min           0
# evaluation/env_infos/actions Mean                  0
# evaluation/env_infos/actions Std                   0
# evaluation/env_infos/actions Max                   0
# evaluation/env_infos/actions Min                   0
# evaluation/env_infos/final/Y_Pos_1 Mean          149
# evaluation/env_infos/final/Y_Pos_1 Std             0
# evaluation/env_infos/final/Y_Pos_1 Max           149
# evaluation/env_infos/final/Y_Pos_1 Min           149
# evaluation/env_infos/initial/Y_Pos_1 Mean        149
# evaluation/env_infos/initial/Y_Pos_1 Std           0
# evaluation/env_infos/initial/Y_Pos_1 Max         149
# evaluation/env_infos/initial/Y_Pos_1 Min         149
# evaluation/env_infos/Y_Pos_1 Mean                149
# evaluation/env_infos/Y_Pos_1 Std                   0
# evaluation/env_infos/Y_Pos_1 Max                 149
# evaluation/env_infos/Y_Pos_1 Min                 149
# evaluation/env_infos/final/Velocity_y Mean         5.55499
# evaluation/env_infos/final/Velocity_y Std          2.92257
# evaluation/env_infos/final/Velocity_y Max         10
# evaluation/env_infos/final/Velocity_y Min          1
# evaluation/env_infos/initial/Velocity_y Mean       5.55499
# evaluation/env_infos/initial/Velocity_y Std        2.92257
# evaluation/env_infos/initial/Velocity_y Max       10
# evaluation/env_infos/initial/Velocity_y Min        1
# evaluation/env_infos/Velocity_y Mean               5.47857
# evaluation/env_infos/Velocity_y Std                2.91105
# evaluation/env_infos/Velocity_y Max               10
# evaluation/env_infos/Velocity_y Min                1
# evaluation/env_infos/final/X_pos_2 Mean          349.217
# evaluation/env_infos/final/X_pos_2 Std           133.451
# evaluation/env_infos/final/X_pos_2 Max           579
# evaluation/env_infos/final/X_pos_2 Min           120
# evaluation/env_infos/initial/X_pos_2 Mean        349.217
# evaluation/env_infos/initial/X_pos_2 Std         133.451
# evaluation/env_infos/initial/X_pos_2 Max         579
# evaluation/env_infos/initial/X_pos_2 Min         120
# evaluation/env_infos/X_pos_2 Mean                345.053
# evaluation/env_infos/X_pos_2 Std                 139.079
# evaluation/env_infos/X_pos_2 Max                 579
# evaluation/env_infos/X_pos_2 Min                 120
# time/data storing (s)                              0.000283688
# time/evaluation sampling (s)                       4.30915
# time/exploration sampling (s)                      0.0100539
# time/logging (s)                                   0.0579816
# time/saving (s)                                    0.0078669
# time/training (s)                                  2.36801
# time/epoch (s)                                     6.75334
# time/total (s)                                    34.8776
# Epoch                                              4
# ---------------------------------------------  ---------------
# 2019-06-09 01:34:42.179368 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 5 finished
# ---------------------------------------------  ---------------
# replay_buffer/size                              1060
# trainer/QF Loss                                    4.83815
# trainer/Y Predictions Mean                        -1.58203
# trainer/Y Predictions Std                          2.0299
# trainer/Y Predictions Max                         -0.621315
# trainer/Y Predictions Min                         -8.90276
# exploration/num steps total                     1060
# exploration/num paths total                       25
# exploration/path length Mean                       5
# exploration/path length Std                        3
# exploration/path length Max                        8
# exploration/path length Min                        2
# exploration/Rewards Mean                          -2.9
# exploration/Rewards Std                            5.7
# exploration/Rewards Max                           -1
# exploration/Rewards Min                          -20
# exploration/Returns Mean                         -14.5
# exploration/Returns Std                           12.5
# exploration/Returns Max                           -2
# exploration/Returns Min                          -27
# exploration/Actions Mean                          75.4
# exploration/Actions Std                           21.9645
# exploration/Actions Max                           93
# exploration/Actions Min                           31
# exploration/Num Paths                              2
# exploration/Average Returns                      -14.5
# exploration/env_infos/final/actions Mean           0
# exploration/env_infos/final/actions Std            0
# exploration/env_infos/final/actions Max            0
# exploration/env_infos/final/actions Min            0
# exploration/env_infos/initial/actions Mean         0
# exploration/env_infos/initial/actions Std          0
# exploration/env_infos/initial/actions Max          0
# exploration/env_infos/initial/actions Min          0
# exploration/env_infos/actions Mean                 0
# exploration/env_infos/actions Std                  0
# exploration/env_infos/actions Max                  0
# exploration/env_infos/actions Min                  0
# exploration/env_infos/final/Y_Pos_1 Mean         198
# exploration/env_infos/final/Y_Pos_1 Std            0
# exploration/env_infos/final/Y_Pos_1 Max          198
# exploration/env_infos/final/Y_Pos_1 Min          198
# exploration/env_infos/initial/Y_Pos_1 Mean       198
# exploration/env_infos/initial/Y_Pos_1 Std          0
# exploration/env_infos/initial/Y_Pos_1 Max        198
# exploration/env_infos/initial/Y_Pos_1 Min        198
# exploration/env_infos/Y_Pos_1 Mean               198
# exploration/env_infos/Y_Pos_1 Std                  0
# exploration/env_infos/Y_Pos_1 Max                198
# exploration/env_infos/Y_Pos_1 Min                198
# exploration/env_infos/final/Velocity_y Mean        3
# exploration/env_infos/final/Velocity_y Std         0
# exploration/env_infos/final/Velocity_y Max         3
# exploration/env_infos/final/Velocity_y Min         3
# exploration/env_infos/initial/Velocity_y Mean      3
# exploration/env_infos/initial/Velocity_y Std       0
# exploration/env_infos/initial/Velocity_y Max       3
# exploration/env_infos/initial/Velocity_y Min       3
# exploration/env_infos/Velocity_y Mean              3
# exploration/env_infos/Velocity_y Std               0
# exploration/env_infos/Velocity_y Max               3
# exploration/env_infos/Velocity_y Min               3
# exploration/env_infos/final/X_pos_2 Mean         302
# exploration/env_infos/final/X_pos_2 Std          144
# exploration/env_infos/final/X_pos_2 Max          446
# exploration/env_infos/final/X_pos_2 Min          158
# exploration/env_infos/initial/X_pos_2 Mean       302
# exploration/env_infos/initial/X_pos_2 Std        144
# exploration/env_infos/initial/X_pos_2 Max        446
# exploration/env_infos/initial/X_pos_2 Min        158
# exploration/env_infos/X_pos_2 Mean               215.6
# exploration/env_infos/X_pos_2 Std                115.2
# exploration/env_infos/X_pos_2 Max                446
# exploration/env_infos/X_pos_2 Min                158
# evaluation/num steps total                     29918
# evaluation/num paths total                      1937
# evaluation/path length Mean                        8.01282
# evaluation/path length Std                         2.12958
# evaluation/path length Max                        16
# evaluation/path length Min                         7
# evaluation/Rewards Mean                           -3.3632
# evaluation/Rewards Std                             6.28364
# evaluation/Rewards Max                            20
# evaluation/Rewards Min                           -20
# evaluation/Returns Mean                          -26.9487
# evaluation/Returns Std                             2.56591
# evaluation/Returns Max                             9
# evaluation/Returns Min                           -35
# evaluation/Actions Mean                           78.363
# evaluation/Actions Std                            21.581
# evaluation/Actions Max                            93
# evaluation/Actions Min                            31
# evaluation/Num Paths                             624
# evaluation/Average Returns                       -26.9487
# evaluation/env_infos/final/actions Mean            0
# evaluation/env_infos/final/actions Std             0
# evaluation/env_infos/final/actions Max             0
# evaluation/env_infos/final/actions Min             0
# evaluation/env_infos/initial/actions Mean          0
# ...
# exploration/env_infos/final/Velocity_y Min          4
# exploration/env_infos/initial/Velocity_y Mean       4
# exploration/env_infos/initial/Velocity_y Std        0
# exploration/env_infos/initial/Velocity_y Max        4
# exploration/env_infos/initial/Velocity_y Min        4
# exploration/env_infos/Velocity_y Mean               4
# exploration/env_infos/Velocity_y Std                0
# exploration/env_infos/Velocity_y Max                4
# exploration/env_infos/Velocity_y Min                4
# exploration/env_infos/final/X_pos_2 Mean          344.5
# exploration/env_infos/final/X_pos_2 Std           138.5
# exploration/env_infos/final/X_pos_2 Max           483
# exploration/env_infos/final/X_pos_2 Min           206
# exploration/env_infos/initial/X_pos_2 Mean        344.5
# exploration/env_infos/initial/X_pos_2 Std         138.5
# exploration/env_infos/initial/X_pos_2 Max         483
# exploration/env_infos/initial/X_pos_2 Min         206
# exploration/env_infos/X_pos_2 Mean                261.4
# exploration/env_infos/X_pos_2 Std                 110.8
# exploration/env_infos/X_pos_2 Max                 483
# exploration/env_infos/X_pos_2 Min                 206
# evaluation/num steps total                     413382
# evaluation/num paths total                      20141
# evaluation/path length Mean                        12.3005
# evaluation/path length Std                          4.16037
# evaluation/path length Max                         42
# evaluation/path length Min                          7
# evaluation/Rewards Mean                            -2.54465
# evaluation/Rewards Std                              5.19254
# evaluation/Rewards Max                             -1
# evaluation/Rewards Min                            -20
# evaluation/Returns Mean                           -31.3005
# evaluation/Returns Std                              4.16037
# evaluation/Returns Max                            -26
# evaluation/Returns Min                            -61
# evaluation/Actions Mean                            48.3947
# evaluation/Actions Std                             29.3556
# evaluation/Actions Max                             98
# evaluation/Actions Min                              1
# evaluation/Num Paths                              406
# evaluation/Average Returns                        -31.3005
# evaluation/env_infos/final/actions Mean             0
# evaluation/env_infos/final/actions Std              0
# evaluation/env_infos/final/actions Max              0
# evaluation/env_infos/final/actions Min              0
# evaluation/env_infos/initial/actions Mean           0
# evaluation/env_infos/initial/actions Std            0
# evaluation/env_infos/initial/actions Max            0
# evaluation/env_infos/initial/actions Min            0
# evaluation/env_infos/actions Mean                   0
# evaluation/env_infos/actions Std                    0
# evaluation/env_infos/actions Max                    0
# evaluation/env_infos/actions Min                    0
# evaluation/env_infos/final/Y_Pos_1 Mean           149
# evaluation/env_infos/final/Y_Pos_1 Std              0
# evaluation/env_infos/final/Y_Pos_1 Max            149
# evaluation/env_infos/final/Y_Pos_1 Min            149
# evaluation/env_infos/initial/Y_Pos_1 Mean         149
# evaluation/env_infos/initial/Y_Pos_1 Std            0
# evaluation/env_infos/initial/Y_Pos_1 Max          149
# evaluation/env_infos/initial/Y_Pos_1 Min          149
# evaluation/env_infos/Y_Pos_1 Mean                 149
# evaluation/env_infos/Y_Pos_1 Std                    0
# evaluation/env_infos/Y_Pos_1 Max                  149
# evaluation/env_infos/Y_Pos_1 Min                  149
# evaluation/env_infos/final/Velocity_y Mean          5.47044
# evaluation/env_infos/final/Velocity_y Std           2.82108
# evaluation/env_infos/final/Velocity_y Max          10
# evaluation/env_infos/final/Velocity_y Min           1
# evaluation/env_infos/initial/Velocity_y Mean        5.47044
# evaluation/env_infos/initial/Velocity_y Std         2.82108
# evaluation/env_infos/initial/Velocity_y Max        10
# evaluation/env_infos/initial/Velocity_y Min         1
# evaluation/env_infos/Velocity_y Mean                5.42791
# evaluation/env_infos/Velocity_y Std                 2.84405
# evaluation/env_infos/Velocity_y Max                10
# evaluation/env_infos/Velocity_y Min                 1
# evaluation/env_infos/final/X_pos_2 Mean           344.222
# evaluation/env_infos/final/X_pos_2 Std            128.504
# evaluation/env_infos/final/X_pos_2 Max            580
# evaluation/env_infos/final/X_pos_2 Min            120
# evaluation/env_infos/initial/X_pos_2 Mean         344.222
# evaluation/env_infos/initial/X_pos_2 Std          128.504
# evaluation/env_infos/initial/X_pos_2 Max          580
# evaluation/env_infos/initial/X_pos_2 Min          120
# evaluation/env_infos/X_pos_2 Mean                 336.858
# evaluation/env_infos/X_pos_2 Std                  134.031
# evaluation/env_infos/X_pos_2 Max                  580
# evaluation/env_infos/X_pos_2 Min                  120
# time/data storing (s)                               0.000149029
# time/evaluation sampling (s)                        4.33344
# time/exploration sampling (s)                       0.0118681
# time/logging (s)                                    0.0937357
# time/saving (s)                                     0.00677444
# time/training (s)                                   2.34684
# time/epoch (s)                                      6.79281
# time/total (s)                                    552.687
# Epoch                                              82
# ---------------------------------------------  ----------------
# 2019-06-09 01:43:20.204505 Pacific Daylight Time | [ddqn-train_2019_06_09_01_34_02_0000--s-0] Epoch 83 finished
# ---------------------------------------------  ----------------
# replay_buffer/size                               1840
# trainer/QF Loss                                     0.174929
# trainer/Y Predictions Mean                        -12.9776
# trainer/Y Predictions Std                           4.47253
# trainer/Y Predictions Max                          -6.58664
# trainer/Y Predictions Min                         -20.1429
# exploration/num steps total                      1840
# exploration/num paths total                       115
# exploration/path length Mean                       10
# exploration/path length Std                         0
# exploration/path length Max                        10
# exploration/path length Min                        10
# exploration/Rewards Mean                           -1
# exploration/Rewards Std                             0
# exploration/Rewards Max                            -1
# exploration/Rewards Min                            -1
# exploration/Returns Mean                          -10
# exploration/Returns Std                             0
# exploration/Returns Max                           -10
# exploration/Returns Min                           -10
# exploration/Actions Mean                           43.6
# exploration/Actions Std                            19.2624
# exploration/Actions Max                            72
# exploration/Actions Min                            19
# exploration/Num Paths                               1
# exploration/Average Returns                       -10
# exploration/env_infos/final/actions Mean            0
# exploration/env_infos/final/actions Std             0
# exploration/env_infos/final/actions Max             0
# exploration/env_infos/final/actions Min             0
# exploration/env_infos/initial/actions Mean          0
# exploration/env_infos/initial/actions Std           0
# exploration/env_infos/initial/actions Max           0
# exploration/env_infos/initial/actions Min           0
# exploration/env_infos/actions Mean                  0
# exploration/env_infos/actions Std                   0
# exploration/env_infos/actions Max                   0
# exploration/env_infos/actions Min                   0
# exploration/env_infos/final/Y_Pos_1 Mean          198
# exploration/env_infos/final/Y_Pos_1 Std             0
# exploration/env_infos/final/Y_Pos_1 Max           198
# exploration/env_infos/final/Y_Pos_1 Min           198
# exploration/env_infos/initial/Y_Pos_1 Mean        198
# exploration/env_infos/initial/Y_Pos_1 Std           0
# exploration/env_infos/initial/Y_Pos_1 Max         198
# exploration/env_infos/initial/Y_Pos_1 Min         198
# exploration/env_infos/Y_Pos_1 Mean                198
# exploration/env_infos/Y_Pos_1 Std                   0
# exploration/env_infos/Y_Pos_1 Max                 198
# exploration/env_infos/Y_Pos_1 Min                 198
# exploration/env_infos/final/Velocity_y Mean         6
# exploration/env_infos/final/Velocity_y Std          0
# exploration/env_infos/final/Velocity_y Max          6
# exploration/env_infos/final/Velocity_y Min          6
# exploration/env_infos/initial/Velocity_y Mean       6
# exploration/env_infos/initial/Velocity_y Std        0
# exploration/env_infos/initial/Velocity_y Max        6
# exploration/env_infos/initial/Velocity_y Min        6
# exploration/env_infos/Velocity_y Mean               6
# exploration/env_infos/Velocity_y Std                0
# exploration/env_infos/Velocity_y Max                6
# exploration/env_infos/Velocity_y Min                6
# exploration/env_infos/final/X_pos_2 Mean          420
# exploration/env_infos/final/X_pos_2 Std             0
# exploration/env_infos/final/X_pos_2 Max           420
# exploration/env_infos/final/X_pos_2 Min           420
# exploration/env_infos/initial/X_pos_2 Mean        420
# exploration/env_infos/initial/X_pos_2 Std           0
# exploration/env_infos/initial/X_pos_2 Max         420
# exploration/env_infos/initial/X_pos_2 Min         420
# exploration/env_infos/X_pos_2 Mean                420
# exploration/env_infos/X_pos_2 Std                   0
# exploration/env_infos/X_pos_2 Max                 420
# exploration/env_infos/X_pos_2 Min                 420
# evaluation/num steps total                     418376
# evaluation/num paths total                      20401
# evaluation/path length Mean                        19.2077
# evaluation/path length Std                         16.751
# evaluation/path length Max                        100
# evaluation/path length Min                          9
# evaluation/Rewards Mean                            -1.97777
# evaluation/Rewards Std                              4.19782
# evaluation/Rewards Max                             -1
# evaluation/Rewards Min                            -20
# evaluation/Returns Mean                           -37.9885
# evaluation/Returns Std                             15.7889
# evaluation/Returns Max                            -28
# evaluation/Returns Min                           -119
# evaluation/Actions Mean                            30.8054
# evaluation/Actions Std                             24.0668
# evaluation/Actions Max                             98
# evaluation/Actions Min                              1
# evaluation/Num Paths                              260
# evaluation/Average Returns                        -37.9885
# evaluation/env_infos/final/actions Mean             0
# evaluation/env_infos/final/actions Std              0
# evaluation/env_infos/final/actions Max              0
# evaluation/env_infos/final/actions Min              0
# evaluation/env_infos/initial/actions Mean           0
# evaluation/env_infos/initial/actions Std            0
# evaluation/env_infos/initial/actions Max            0
# evaluation/env_infos/initial/actions Min            0
# evaluation/env_infos/actions Mean                   0
# evaluation/env_infos/actions Std                    0
# evaluation/env_infos/actions Max                    0
# evaluation/env_infos/actions Min                    0
# evaluation/env_infos/final/Y_Pos_1 Mean           149
# evaluation/env_infos/final/Y_Pos_1 Std              0
# evaluation/env_infos/final/Y_Pos_1 Max            149
# evaluation/env_infos/final/Y_Pos_1 Min            149
# evaluation/env_infos/initial/Y_Pos_1 Mean         149
# evaluation/env_infos/initial/Y_Pos_1 Std            0
# evaluation/env_infos/initial/Y_Pos_1 Max          149
# evaluation/env_infos/initial/Y_Pos_1 Min          149
# evaluation/env_infos/Y_Pos_1 Mean                 149
# evaluation/env_infos/Y_Pos_1 Std                    0
# evaluation/env_infos/Y_Pos_1 Max                  149
# evaluation/env_infos/Y_Pos_1 Min                  149
# evaluation/env_infos/final/Velocity_y Mean          5.73077
# evaluation/env_infos/final/Velocity_y Std           2.92282
# evaluation/env_infos/final/Velocity_y Max          10
# evaluation/env_infos/final/Velocity_y Min           1
# evaluation/env_infos/initial/Velocity_y Mean        5.73077
# evaluation/env_infos/initial/Velocity_y Std         2.92282
# evaluation/env_infos/initial/Velocity_y Max        10
# evaluation/env_infos/initial/Velocity_y Min         1
# evaluation/env_infos/Velocity_y Mean                5.27213
# evaluation/env_infos/Velocity_y Std                 2.74454
# evaluation/env_infos/Velocity_y Max                10
# evaluation/env_infos/Velocity_y Min                 1
# evaluation/env_infos/final/X_pos_2 Mean           349.338
# evaluation/env_infos/final/X_pos_2 Std            127.798
# evaluation/env_infos/final/X_pos_2 Max            577
# evaluation/env_infos/final/X_pos_2 Min            120
# evaluation/env_infos/initial/X_pos_2 Mean         349.338
# evaluation/env_infos/initial/X_pos_2 Std          127.798
# evaluation/env_infos/initial/X_pos_2 Max          577
# evaluation/env_infos/initial/X_pos_2 Min          120
# evaluation/env_infos/X_pos_2 Mean                 301.068
# evaluation/env_infos/X_pos_2 Std                  136.513
# evaluation/env_infos/X_pos_2 Max                  577
# evaluation/env_infos/X_pos_2 Min                  120
# time/data storing (s)                               0.000125217
# time/evaluation sampling (s)                        4.27141
# time/exploration sampling (s)                       0.00925127
# time/logging (s)                                    0.046056
# time/saving (s)                                     0.00605803
# time/training (s)                                   1.97289
# time/epoch (s)                                      6.3058
# time/total (s)                                    559.176
# Epoch                                              83
# ---------------------------------------------  ----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-275db01aba73> in <module>()
#      22     setup_logger('./ddqn-train', variant=variant)
#      23     # ptu.set_gpu_mode(True)  # optionally set the GPU (default=False)
# ---> 24     experiment(variant)
#
# <ipython-input-1-46ac0e71559b> in experiment(variant)
#      65     )
#      66     algorithm.to(ptu.device)
# ---> 67     algorithm.train()
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\core\rl_algorithm.py in train(self, start_epoch)
#      44     def train(self, start_epoch=0):
#      45         self._start_epoch = start_epoch
# ---> 46         self._train()
#      47
#      48     def _train(self):
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\core\batch_rl_algorithm.py in _train(self)
#      78                     train_data = self.replay_buffer.random_batch(
#      79                         self.batch_size)
# ---> 80                     self.trainer.train(train_data)
#      81                 gt.stamp('training', unique=False)
#      82                 self.training_mode(False)
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\torch\torch_rl_algorithm.py in train(self, np_batch)
#      38         self._num_train_steps += 1
#      39         batch = np_to_pytorch_batch(np_batch)
# ---> 40         self.train_from_torch(batch)
#      41
#      42     def get_diagnostics(self):
#
# h:\work\psu\ece 510(deep learning theory and practices)\project\rlkit\rlkit\torch\dqn\double_dqn.py in train_from_torch(self, batch)
#      20
#      21         best_action_idxs = self.qf(next_obs).max(
# ---> 22             1, keepdim=True
#      23         )[1]
#      24         target_q_values = self.target_qf(next_obs).gather(
#
# KeyboardInterrupt:

# %%
env = gym.make('Physics_RL-v0')
env.reset()
# Out:
# (10, 174, 421, 10)

# %%
#env.observation_space.low.size
env.step(10)
# Out:
# ((180, 174, 421, 95),
#  0,
#  False,
#  {'Velocity_y': 5,
#   'X_pos_2': 421,
#   'Y_Pos_1': 278,
#   'actions': [10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10,
#    10]})
